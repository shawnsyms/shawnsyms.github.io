# %% [markdown]
# ### Imports

# %%
# pandas and numpy
import pandas as pd
import numpy as np

# nltk imports
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer

# sci-kit learn imports
from sklearn.compose import make_column_transformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.pipeline import Pipeline, make_pipeline

# Presentation and visuals
import seaborn as sns
import matplotlib.pyplot as plt

# This magic line will allow you to generate plots
# within the Jupyter notebook.
# %matplotlib inline
from pprint import pprint
pd.options.display.max_seq_items = 2000
pd.options.display.max_rows = 4000
# pd.set_option(display.max_columns), None

# other imports
import json
import lxml
from lxml import html
import random
import regex as re
import requests
import time
import urllib.request
from datetime import datetime

# %% [markdown]
# # Data acquisition

# %%
isbn = pd.read_csv('../data/data_acquisition/international2_for_download.csv')
isbn = isbn.applymap(str)
isbn.dtypes
# Out:
# isbn        object
# title       object
# authors     object
# overview    object
# dtype: object

# %%
isbn = isbn[:5000]
isbn
# Out:
#                isbn title authors overview
# 0     9780061987465   nan     nan      nan
# 1     9780061988400   nan     nan      nan
# 2     9780061988424   nan     nan      nan
# 3     9780061989162   nan     nan      nan
# 4     9780061989339   nan     nan      nan
# ...             ...   ...     ...      ...
# 4995  9780130908452   nan     nan      nan
# 4996  9780130909022   nan     nan      nan
# 4997  9780130909220   nan     nan      nan
# 4998  9780130909305   nan     nan      nan
# 4999  9780130909473   nan     nan      nan
#
# [5000 rows x 4 columns]

# %%
for j in range(len(isbn)):

    header = {'Authorization': '44023_23ab132f3977ad9849e8f1a5d7dc73bf'}
    base_url = ('https://api2.isbndb.com/book/')
    response = requests.get(base_url + isbn['isbn'][j], headers=header)
    payload = response.json()
      
    try:
        isbn['title'][j] = payload['book']['title']
    
    except:
        isbn['title'][j] = np.nan
    
    try:
        isbn['authors'][j] = payload['book']['authors']
    
    except:
        isbn['authors'][j] = np.nan
              
    try:
        isbn['overview'][j] = payload['book']['overview']
    
    except:
        isbn['overview'][j] = np.nan
  
    print('Info downloaded for book ' + str(j + 1) + ' of ' +  str(len(isbn)) + ' books.')
              
    time.sleep(1)
# Out:
# Info downloaded for book 1 of 5000 books.
# Info downloaded for book 2 of 5000 books.
# Info downloaded for book 3 of 5000 books.
# Info downloaded for book 4 of 5000 books.
# Info downloaded for book 5 of 5000 books.
# Info downloaded for book 6 of 5000 books.
# Info downloaded for book 7 of 5000 books.
# Info downloaded for book 8 of 5000 books.
# Info downloaded for book 9 of 5000 books.
# Info downloaded for book 10 of 5000 books.
# Info downloaded for book 11 of 5000 books.
# Info downloaded for book 12 of 5000 books.
# Info downloaded for book 13 of 5000 books.
# Info downloaded for book 14 of 5000 books.
# Info downloaded for book 15 of 5000 books.
# Info downloaded for book 16 of 5000 books.
# Info downloaded for book 17 of 5000 books.
# Info downloaded for book 18 of 5000 books.
# Info downloaded for book 19 of 5000 books.
# Info downloaded for book 20 of 5000 books.
# Info downloaded for book 21 of 5000 books.
# Info downloaded for book 22 of 5000 books.
# Info downloaded for book 23 of 5000 books.
# Info downloaded for book 24 of 5000 books.
# Info downloaded for book 25 of 5000 books.
# Info downloaded for book 26 of 5000 books.
# Info downloaded for book 27 of 5000 books.
# Info downloaded for book 28 of 5000 books.
# Info downloaded for book 29 of 5000 books.
# Info downloaded for book 30 of 5000 books.
# Info downloaded for book 31 of 5000 books.
# Info downloaded for book 32 of 5000 books.
# Info downloaded for book 33 of 5000 books.
# Info downloaded for book 34 of 5000 books.
# Info downloaded for book 35 of 5000 books.
# Info downloaded for book 36 of 5000 books.
# Info downloaded for book 37 of 5000 books.
# Info downloaded for book 38 of 5000 books.
# Info downloaded for book 39 of 5000 books.
# Info downloaded for book 40 of 5000 books.
# Info downloaded for book 41 of 5000 books.
# Info downloaded for book 42 of 5000 books.
# Info downloaded for book 43 of 5000 books.
# Info downloaded for book 44 of 5000 books.
# Info downloaded for book 45 of 5000 books.
# Info downloaded for book 46 of 5000 books.
# Info downloaded for book 47 of 5000 books.
# Info downloaded for book 48 of 5000 books.
# Info downloaded for book 49 of 5000 books.
# Info downloaded for book 50 of 5000 books.
# Info downloaded for book 51 of 5000 books.
# Info downloaded for book 52 of 5000 books.
# Info downloaded for book 53 of 5000 books.
# Info downloaded for book 54 of 5000 books.
# Info downloaded for book 55 of 5000 books.
# Info downloaded for book 56 of 5000 books.
# Info downloaded for book 57 of 5000 books.
# Info downloaded for book 58 of 5000 books.
# Info downloaded for book 59 of 5000 books.
# Info downloaded for book 60 of 5000 books.
# Info downloaded for book 61 of 5000 books.
# Info downloaded for book 62 of 5000 books.
# Info downloaded for book 63 of 5000 books.
# Info downloaded for book 64 of 5000 books.
# Info downloaded for book 65 of 5000 books.
# Info downloaded for book 66 of 5000 books.
# Info downloaded for book 67 of 5000 books.
# Info downloaded for book 68 of 5000 books.
# Info downloaded for book 69 of 5000 books.
# Info downloaded for book 70 of 5000 books.
# Info downloaded for book 71 of 5000 books.
# Info downloaded for book 72 of 5000 books.
# Info downloaded for book 73 of 5000 books.
# Info downloaded for book 74 of 5000 books.
# Info downloaded for book 75 of 5000 books.
# Info downloaded for book 76 of 5000 books.
# Info downloaded for book 77 of 5000 books.
# Info downloaded for book 78 of 5000 books.
# Info downloaded for book 79 of 5000 books.
# Info downloaded for book 80 of 5000 books.
# Info downloaded for book 81 of 5000 books.
# Info downloaded for book 82 of 5000 books.
# Info downloaded for book 83 of 5000 books.
# Info downloaded for book 84 of 5000 books.
# Info downloaded for book 85 of 5000 books.
# Info downloaded for book 86 of 5000 books.
# Info downloaded for book 87 of 5000 books.
# Info downloaded for book 88 of 5000 books.
# Info downloaded for book 89 of 5000 books.
# Info downloaded for book 90 of 5000 books.
# Info downloaded for book 91 of 5000 books.
# Info downloaded for book 92 of 5000 books.
# Info downloaded for book 93 of 5000 books.
# Info downloaded for book 94 of 5000 books.
# Info downloaded for book 95 of 5000 books.
# Info downloaded for book 96 of 5000 books.
# Info downloaded for book 97 of 5000 books.
# Info downloaded for book 98 of 5000 books.
# Info downloaded for book 99 of 5000 books.
# Info downloaded for book 100 of 5000 books.
# Info downloaded for book 101 of 5000 books.
# Info downloaded for book 102 of 5000 books.
# Info downloaded for book 103 of 5000 books.
# Info downloaded for book 104 of 5000 books.
# Info downloaded for book 105 of 5000 books.
# Info downloaded for book 106 of 5000 books.
# Info downloaded for book 107 of 5000 books.
# Info downloaded for book 108 of 5000 books.
# Info downloaded for book 109 of 5000 books.
# Info downloaded for book 110 of 5000 books.
# Info downloaded for book 111 of 5000 books.
# Info downloaded for book 112 of 5000 books.
# Info downloaded for book 113 of 5000 books.
# Info downloaded for book 114 of 5000 books.
# Info downloaded for book 115 of 5000 books.
# Info downloaded for book 116 of 5000 books.
# Info downloaded for book 117 of 5000 books.
# Info downloaded for book 118 of 5000 books.
# Info downloaded for book 119 of 5000 books.
# Info downloaded for book 120 of 5000 books.
# Info downloaded for book 121 of 5000 books.
# Info downloaded for book 122 of 5000 books.
# Info downloaded for book 123 of 5000 books.
# Info downloaded for book 124 of 5000 books.
# Info downloaded for book 125 of 5000 books.
# Info downloaded for book 126 of 5000 books.
# Info downloaded for book 127 of 5000 books.
# Info downloaded for book 128 of 5000 books.
# Info downloaded for book 129 of 5000 books.
# Info downloaded for book 130 of 5000 books.
# Info downloaded for book 131 of 5000 books.
# Info downloaded for book 132 of 5000 books.
# Info downloaded for book 133 of 5000 books.
# Info downloaded for book 134 of 5000 books.
# Info downloaded for book 135 of 5000 books.
# Info downloaded for book 136 of 5000 books.
# Info downloaded for book 137 of 5000 books.
# Info downloaded for book 138 of 5000 books.
# Info downloaded for book 139 of 5000 books.
# Info downloaded for book 140 of 5000 books.
# Info downloaded for book 141 of 5000 books.
# Info downloaded for book 142 of 5000 books.
# Info downloaded for book 143 of 5000 books.
# Info downloaded for book 144 of 5000 books.
# Info downloaded for book 145 of 5000 books.
# Info downloaded for book 146 of 5000 books.
# Info downloaded for book 147 of 5000 books.
# Info downloaded for book 148 of 5000 books.
# Info downloaded for book 149 of 5000 books.
# Info downloaded for book 150 of 5000 books.
# Info downloaded for book 151 of 5000 books.
# Info downloaded for book 152 of 5000 books.
# Info downloaded for book 153 of 5000 books.
# Info downloaded for book 154 of 5000 books.
# Info downloaded for book 155 of 5000 books.
# Info downloaded for book 156 of 5000 books.
# Info downloaded for book 157 of 5000 books.
# Info downloaded for book 158 of 5000 books.
# Info downloaded for book 159 of 5000 books.
# Info downloaded for book 160 of 5000 books.
# Info downloaded for book 161 of 5000 books.
# Info downloaded for book 162 of 5000 books.
# Info downloaded for book 163 of 5000 books.
# Info downloaded for book 164 of 5000 books.
# Info downloaded for book 165 of 5000 books.
# Info downloaded for book 166 of 5000 books.
# Info downloaded for book 167 of 5000 books.
# Info downloaded for book 168 of 5000 books.
# Info downloaded for book 169 of 5000 books.
# Info downloaded for book 170 of 5000 books.
# Info downloaded for book 171 of 5000 books.
# Info downloaded for book 172 of 5000 books.
# Info downloaded for book 173 of 5000 books.
# Info downloaded for book 174 of 5000 books.
# Info downloaded for book 175 of 5000 books.
# Info downloaded for book 176 of 5000 books.
# Info downloaded for book 177 of 5000 books.
# Info downloaded for book 178 of 5000 books.
# Info downloaded for book 179 of 5000 books.
# Info downloaded for book 180 of 5000 books.
# Info downloaded for book 181 of 5000 books.
# Info downloaded for book 182 of 5000 books.
# Info downloaded for book 183 of 5000 books.
# Info downloaded for book 184 of 5000 books.
# Info downloaded for book 185 of 5000 books.
# Info downloaded for book 186 of 5000 books.
# Info downloaded for book 187 of 5000 books.
# Info downloaded for book 188 of 5000 books.
# Info downloaded for book 189 of 5000 books.
# Info downloaded for book 190 of 5000 books.
# Info downloaded for book 191 of 5000 books.
# Info downloaded for book 192 of 5000 books.
# Info downloaded for book 193 of 5000 books.
# Info downloaded for book 194 of 5000 books.
# Info downloaded for book 195 of 5000 books.
# Info downloaded for book 196 of 5000 books.
# Info downloaded for book 197 of 5000 books.
# Info downloaded for book 198 of 5000 books.
# Info downloaded for book 199 of 5000 books.
# Info downloaded for book 200 of 5000 books.
# Info downloaded for book 201 of 5000 books.
# Info downloaded for book 202 of 5000 books.
# Info downloaded for book 203 of 5000 books.
# Info downloaded for book 204 of 5000 books.
# Info downloaded for book 205 of 5000 books.
# Info downloaded for book 206 of 5000 books.
# Info downloaded for book 207 of 5000 books.
# Info downloaded for book 208 of 5000 books.
# Info downloaded for book 209 of 5000 books.
# Info downloaded for book 210 of 5000 books.
# Info downloaded for book 211 of 5000 books.
# Info downloaded for book 212 of 5000 books.
# Info downloaded for book 213 of 5000 books.
# Info downloaded for book 214 of 5000 books.
# Info downloaded for book 215 of 5000 books.
# Info downloaded for book 216 of 5000 books.
# Info downloaded for book 217 of 5000 books.
# Info downloaded for book 218 of 5000 books.
# Info downloaded for book 219 of 5000 books.
# Info downloaded for book 220 of 5000 books.
# Info downloaded for book 221 of 5000 books.
# Info downloaded for book 222 of 5000 books.
# Info downloaded for book 223 of 5000 books.
# Info downloaded for book 224 of 5000 books.
# Info downloaded for book 225 of 5000 books.
# Info downloaded for book 226 of 5000 books.
# Info downloaded for book 227 of 5000 books.
# Info downloaded for book 228 of 5000 books.
# Info downloaded for book 229 of 5000 books.
# Info downloaded for book 230 of 5000 books.
# Info downloaded for book 231 of 5000 books.
# Info downloaded for book 232 of 5000 books.
# Info downloaded for book 233 of 5000 books.
# Info downloaded for book 234 of 5000 books.
# Info downloaded for book 235 of 5000 books.
# Info downloaded for book 236 of 5000 books.
# Info downloaded for book 237 of 5000 books.
# Info downloaded for book 238 of 5000 books.
# Info downloaded for book 239 of 5000 books.
# Info downloaded for book 240 of 5000 books.
# Info downloaded for book 241 of 5000 books.
# Info downloaded for book 242 of 5000 books.
# Info downloaded for book 243 of 5000 books.
# Info downloaded for book 244 of 5000 books.
# Info downloaded for book 245 of 5000 books.
# Info downloaded for book 246 of 5000 books.
# Info downloaded for book 247 of 5000 books.
# Info downloaded for book 248 of 5000 books.
# Info downloaded for book 249 of 5000 books.
# Info downloaded for book 250 of 5000 books.
# Info downloaded for book 251 of 5000 books.
# Info downloaded for book 252 of 5000 books.
# Info downloaded for book 253 of 5000 books.
# Info downloaded for book 254 of 5000 books.
# Info downloaded for book 255 of 5000 books.
# Info downloaded for book 256 of 5000 books.
# Info downloaded for book 257 of 5000 books.
# Info downloaded for book 258 of 5000 books.
# Info downloaded for book 259 of 5000 books.
# Info downloaded for book 260 of 5000 books.
# Info downloaded for book 261 of 5000 books.
# Info downloaded for book 262 of 5000 books.
# Info downloaded for book 263 of 5000 books.
# Info downloaded for book 264 of 5000 books.
# Info downloaded for book 265 of 5000 books.
# Info downloaded for book 266 of 5000 books.
# Info downloaded for book 267 of 5000 books.
# Info downloaded for book 268 of 5000 books.
# Info downloaded for book 269 of 5000 books.
# Info downloaded for book 270 of 5000 books.
# Info downloaded for book 271 of 5000 books.
# Info downloaded for book 272 of 5000 books.
# Info downloaded for book 273 of 5000 books.
# Info downloaded for book 274 of 5000 books.
# Info downloaded for book 275 of 5000 books.
# Info downloaded for book 276 of 5000 books.
# Info downloaded for book 277 of 5000 books.
# Info downloaded for book 278 of 5000 books.
# Info downloaded for book 279 of 5000 books.
# Info downloaded for book 280 of 5000 books.
# Info downloaded for book 281 of 5000 books.
# Info downloaded for book 282 of 5000 books.
# Info downloaded for book 283 of 5000 books.
# Info downloaded for book 284 of 5000 books.
# Info downloaded for book 285 of 5000 books.
# Info downloaded for book 286 of 5000 books.
# Info downloaded for book 287 of 5000 books.
# Info downloaded for book 288 of 5000 books.
# Info downloaded for book 289 of 5000 books.
# Info downloaded for book 290 of 5000 books.
# Info downloaded for book 291 of 5000 books.
# Info downloaded for book 292 of 5000 books.
# Info downloaded for book 293 of 5000 books.
# Info downloaded for book 294 of 5000 books.
# Info downloaded for book 295 of 5000 books.
# Info downloaded for book 296 of 5000 books.
# Info downloaded for book 297 of 5000 books.
# Info downloaded for book 298 of 5000 books.
# Info downloaded for book 299 of 5000 books.
# Info downloaded for book 300 of 5000 books.
# Info downloaded for book 301 of 5000 books.
# Info downloaded for book 302 of 5000 books.
# Info downloaded for book 303 of 5000 books.
# Info downloaded for book 304 of 5000 books.
# Info downloaded for book 305 of 5000 books.
# Info downloaded for book 306 of 5000 books.
# Info downloaded for book 307 of 5000 books.
# Info downloaded for book 308 of 5000 books.
# Info downloaded for book 309 of 5000 books.
# Info downloaded for book 310 of 5000 books.
# Info downloaded for book 311 of 5000 books.
# Info downloaded for book 312 of 5000 books.
# Info downloaded for book 313 of 5000 books.
# Info downloaded for book 314 of 5000 books.
# Info downloaded for book 315 of 5000 books.
# Info downloaded for book 316 of 5000 books.
# Info downloaded for book 317 of 5000 books.
# Info downloaded for book 318 of 5000 books.
# Info downloaded for book 319 of 5000 books.
# Info downloaded for book 320 of 5000 books.
# Info downloaded for book 321 of 5000 books.
# Info downloaded for book 322 of 5000 books.
# Info downloaded for book 323 of 5000 books.
# Info downloaded for book 324 of 5000 books.
# Info downloaded for book 325 of 5000 books.
# Info downloaded for book 326 of 5000 books.
# Info downloaded for book 327 of 5000 books.
# Info downloaded for book 328 of 5000 books.
# Info downloaded for book 329 of 5000 books.
# Info downloaded for book 330 of 5000 books.
# Info downloaded for book 331 of 5000 books.
# Info downloaded for book 332 of 5000 books.
# Info downloaded for book 333 of 5000 books.
# Info downloaded for book 334 of 5000 books.
# Info downloaded for book 335 of 5000 books.
# Info downloaded for book 336 of 5000 books.
# Info downloaded for book 337 of 5000 books.
# Info downloaded for book 338 of 5000 books.
# Info downloaded for book 339 of 5000 books.
# Info downloaded for book 340 of 5000 books.
# Info downloaded for book 341 of 5000 books.
# Info downloaded for book 342 of 5000 books.
# Info downloaded for book 343 of 5000 books.
# Info downloaded for book 344 of 5000 books.
# Info downloaded for book 345 of 5000 books.
# Info downloaded for book 346 of 5000 books.
# Info downloaded for book 347 of 5000 books.
# Info downloaded for book 348 of 5000 books.
# Info downloaded for book 349 of 5000 books.
# Info downloaded for book 350 of 5000 books.
# Info downloaded for book 351 of 5000 books.
# Info downloaded for book 352 of 5000 books.
# Info downloaded for book 353 of 5000 books.
# Info downloaded for book 354 of 5000 books.
# Info downloaded for book 355 of 5000 books.
# Info downloaded for book 356 of 5000 books.
# Info downloaded for book 357 of 5000 books.
# Info downloaded for book 358 of 5000 books.
# Info downloaded for book 359 of 5000 books.
# Info downloaded for book 360 of 5000 books.
# Info downloaded for book 361 of 5000 books.
# Info downloaded for book 362 of 5000 books.
# Info downloaded for book 363 of 5000 books.
# Info downloaded for book 364 of 5000 books.
# Info downloaded for book 365 of 5000 books.
# Info downloaded for book 366 of 5000 books.
# Info downloaded for book 367 of 5000 books.
# Info downloaded for book 368 of 5000 books.
# Info downloaded for book 369 of 5000 books.
# Info downloaded for book 370 of 5000 books.
# Info downloaded for book 371 of 5000 books.
# Info downloaded for book 372 of 5000 books.
# Info downloaded for book 373 of 5000 books.
# Info downloaded for book 374 of 5000 books.
# Info downloaded for book 375 of 5000 books.
# Info downloaded for book 376 of 5000 books.
# Info downloaded for book 377 of 5000 books.
# Info downloaded for book 378 of 5000 books.
# Info downloaded for book 379 of 5000 books.
# Info downloaded for book 380 of 5000 books.
# Info downloaded for book 381 of 5000 books.
# Info downloaded for book 382 of 5000 books.
# Info downloaded for book 383 of 5000 books.
# Info downloaded for book 384 of 5000 books.
# Info downloaded for book 385 of 5000 books.
# Info downloaded for book 386 of 5000 books.
# Info downloaded for book 387 of 5000 books.
# Info downloaded for book 388 of 5000 books.
# Info downloaded for book 389 of 5000 books.
# Info downloaded for book 390 of 5000 books.
# Info downloaded for book 391 of 5000 books.
# Info downloaded for book 392 of 5000 books.
# Info downloaded for book 393 of 5000 books.
# Info downloaded for book 394 of 5000 books.
# Info downloaded for book 395 of 5000 books.
# Info downloaded for book 396 of 5000 books.
# Info downloaded for book 397 of 5000 books.
# Info downloaded for book 398 of 5000 books.
# Info downloaded for book 399 of 5000 books.
# Info downloaded for book 400 of 5000 books.
# Info downloaded for book 401 of 5000 books.
# Info downloaded for book 402 of 5000 books.
# Info downloaded for book 403 of 5000 books.
# Info downloaded for book 404 of 5000 books.
# Info downloaded for book 405 of 5000 books.
# Info downloaded for book 406 of 5000 books.
# Info downloaded for book 407 of 5000 books.
# Info downloaded for book 408 of 5000 books.
# Info downloaded for book 409 of 5000 books.
# Info downloaded for book 410 of 5000 books.
# Info downloaded for book 411 of 5000 books.
# Info downloaded for book 412 of 5000 books.
# Info downloaded for book 413 of 5000 books.
# Info downloaded for book 414 of 5000 books.
# Info downloaded for book 415 of 5000 books.
# Info downloaded for book 416 of 5000 books.
# Info downloaded for book 417 of 5000 books.
# Info downloaded for book 418 of 5000 books.
# Info downloaded for book 419 of 5000 books.
# Info downloaded for book 420 of 5000 books.
# Info downloaded for book 421 of 5000 books.
# Info downloaded for book 422 of 5000 books.
# Info downloaded for book 423 of 5000 books.
# Info downloaded for book 424 of 5000 books.
# Info downloaded for book 425 of 5000 books.
# Info downloaded for book 426 of 5000 books.
# Info downloaded for book 427 of 5000 books.
# Info downloaded for book 428 of 5000 books.
# Info downloaded for book 429 of 5000 books.
# Info downloaded for book 430 of 5000 books.
# Info downloaded for book 431 of 5000 books.
# Info downloaded for book 432 of 5000 books.
# Info downloaded for book 433 of 5000 books.
# Info downloaded for book 434 of 5000 books.
# Info downloaded for book 435 of 5000 books.
# Info downloaded for book 436 of 5000 books.
# Info downloaded for book 437 of 5000 books.
# Info downloaded for book 438 of 5000 books.
# Info downloaded for book 439 of 5000 books.
# Info downloaded for book 440 of 5000 books.
# Info downloaded for book 441 of 5000 books.
# Info downloaded for book 442 of 5000 books.
# Info downloaded for book 443 of 5000 books.
# Info downloaded for book 444 of 5000 books.
# Info downloaded for book 445 of 5000 books.
# Info downloaded for book 446 of 5000 books.
# Info downloaded for book 447 of 5000 books.
# Info downloaded for book 448 of 5000 books.
# Info downloaded for book 449 of 5000 books.
# Info downloaded for book 450 of 5000 books.
# Info downloaded for book 451 of 5000 books.
# Info downloaded for book 452 of 5000 books.
# Info downloaded for book 453 of 5000 books.
# Info downloaded for book 454 of 5000 books.
# Info downloaded for book 455 of 5000 books.
# Info downloaded for book 456 of 5000 books.
# Info downloaded for book 457 of 5000 books.
# Info downloaded for book 458 of 5000 books.
# Info downloaded for book 459 of 5000 books.
# Info downloaded for book 460 of 5000 books.
# Info downloaded for book 461 of 5000 books.
# Info downloaded for book 462 of 5000 books.
# Info downloaded for book 463 of 5000 books.
# Info downloaded for book 464 of 5000 books.
# Info downloaded for book 465 of 5000 books.
# Info downloaded for book 466 of 5000 books.
# Info downloaded for book 467 of 5000 books.
# Info downloaded for book 468 of 5000 books.
# Info downloaded for book 469 of 5000 books.
# Info downloaded for book 470 of 5000 books.
# Info downloaded for book 471 of 5000 books.
# Info downloaded for book 472 of 5000 books.
# Info downloaded for book 473 of 5000 books.
# Info downloaded for book 474 of 5000 books.
# Info downloaded for book 475 of 5000 books.
# Info downloaded for book 476 of 5000 books.
# Info downloaded for book 477 of 5000 books.
# Info downloaded for book 478 of 5000 books.
# Info downloaded for book 479 of 5000 books.
# Info downloaded for book 480 of 5000 books.
# Info downloaded for book 481 of 5000 books.
# Info downloaded for book 482 of 5000 books.
# Info downloaded for book 483 of 5000 books.
# Info downloaded for book 484 of 5000 books.
# Info downloaded for book 485 of 5000 books.
# Info downloaded for book 486 of 5000 books.
# Info downloaded for book 487 of 5000 books.
# Info downloaded for book 488 of 5000 books.
# Info downloaded for book 489 of 5000 books.
# Info downloaded for book 490 of 5000 books.
# Info downloaded for book 491 of 5000 books.
# Info downloaded for book 492 of 5000 books.
# Info downloaded for book 493 of 5000 books.
# Info downloaded for book 494 of 5000 books.
# Info downloaded for book 495 of 5000 books.
# Info downloaded for book 496 of 5000 books.
# Info downloaded for book 497 of 5000 books.
# Info downloaded for book 498 of 5000 books.
# Info downloaded for book 499 of 5000 books.
# Info downloaded for book 500 of 5000 books.
# Info downloaded for book 501 of 5000 books.
# Info downloaded for book 502 of 5000 books.
# Info downloaded for book 503 of 5000 books.
# Info downloaded for book 504 of 5000 books.
# Info downloaded for book 505 of 5000 books.
# Info downloaded for book 506 of 5000 books.
# Info downloaded for book 507 of 5000 books.
# Info downloaded for book 508 of 5000 books.
# Info downloaded for book 509 of 5000 books.
# Info downloaded for book 510 of 5000 books.
# Info downloaded for book 511 of 5000 books.
# Info downloaded for book 512 of 5000 books.
# Info downloaded for book 513 of 5000 books.
# Info downloaded for book 514 of 5000 books.
# Info downloaded for book 515 of 5000 books.
# Info downloaded for book 516 of 5000 books.
# Info downloaded for book 517 of 5000 books.
# Info downloaded for book 518 of 5000 books.
# Info downloaded for book 519 of 5000 books.
# Info downloaded for book 520 of 5000 books.
# Info downloaded for book 521 of 5000 books.
# Info downloaded for book 522 of 5000 books.
# Info downloaded for book 523 of 5000 books.
# Info downloaded for book 524 of 5000 books.
# Info downloaded for book 525 of 5000 books.
# Info downloaded for book 526 of 5000 books.
# Info downloaded for book 527 of 5000 books.
# Info downloaded for book 528 of 5000 books.
# Info downloaded for book 529 of 5000 books.
# Info downloaded for book 530 of 5000 books.
# Info downloaded for book 531 of 5000 books.
# Info downloaded for book 532 of 5000 books.
# Info downloaded for book 533 of 5000 books.
# Info downloaded for book 534 of 5000 books.
# Info downloaded for book 535 of 5000 books.
# Info downloaded for book 536 of 5000 books.
# Info downloaded for book 537 of 5000 books.
# Info downloaded for book 538 of 5000 books.
# Info downloaded for book 539 of 5000 books.
# Info downloaded for book 540 of 5000 books.
# Info downloaded for book 541 of 5000 books.
# Info downloaded for book 542 of 5000 books.
# Info downloaded for book 543 of 5000 books.
# Info downloaded for book 544 of 5000 books.
# Info downloaded for book 545 of 5000 books.
# Info downloaded for book 546 of 5000 books.
# Info downloaded for book 547 of 5000 books.
# Info downloaded for book 548 of 5000 books.
# Info downloaded for book 549 of 5000 books.
# Info downloaded for book 550 of 5000 books.
# Info downloaded for book 551 of 5000 books.
# Info downloaded for book 552 of 5000 books.
# Info downloaded for book 553 of 5000 books.
# Info downloaded for book 554 of 5000 books.
# Info downloaded for book 555 of 5000 books.
# Info downloaded for book 556 of 5000 books.
# Info downloaded for book 557 of 5000 books.
# Info downloaded for book 558 of 5000 books.
# Info downloaded for book 559 of 5000 books.
# Info downloaded for book 560 of 5000 books.
# Info downloaded for book 561 of 5000 books.
# Info downloaded for book 562 of 5000 books.
# Info downloaded for book 563 of 5000 books.
# Info downloaded for book 564 of 5000 books.
# Info downloaded for book 565 of 5000 books.
# Info downloaded for book 566 of 5000 books.
# Info downloaded for book 567 of 5000 books.
# Info downloaded for book 568 of 5000 books.
# Info downloaded for book 569 of 5000 books.
# Info downloaded for book 570 of 5000 books.
# Info downloaded for book 571 of 5000 books.
# Info downloaded for book 572 of 5000 books.
# Info downloaded for book 573 of 5000 books.
# Info downloaded for book 574 of 5000 books.
# Info downloaded for book 575 of 5000 books.
# Info downloaded for book 576 of 5000 books.
# Info downloaded for book 577 of 5000 books.
# Info downloaded for book 578 of 5000 books.
# Info downloaded for book 579 of 5000 books.
# Info downloaded for book 580 of 5000 books.
# Info downloaded for book 581 of 5000 books.
# Info downloaded for book 582 of 5000 books.
# Info downloaded for book 583 of 5000 books.
# Info downloaded for book 584 of 5000 books.
# Info downloaded for book 585 of 5000 books.
# Info downloaded for book 586 of 5000 books.
# Info downloaded for book 587 of 5000 books.
# Info downloaded for book 588 of 5000 books.
# Info downloaded for book 589 of 5000 books.
# Info downloaded for book 590 of 5000 books.
# Info downloaded for book 591 of 5000 books.
# Info downloaded for book 592 of 5000 books.
# Info downloaded for book 593 of 5000 books.
# Info downloaded for book 594 of 5000 books.
# Info downloaded for book 595 of 5000 books.
# Info downloaded for book 596 of 5000 books.
# Info downloaded for book 597 of 5000 books.
# Info downloaded for book 598 of 5000 books.
# Info downloaded for book 599 of 5000 books.
# Info downloaded for book 600 of 5000 books.
# Info downloaded for book 601 of 5000 books.
# Info downloaded for book 602 of 5000 books.
# Info downloaded for book 603 of 5000 books.
# Info downloaded for book 604 of 5000 books.
# Info downloaded for book 605 of 5000 books.
# Info downloaded for book 606 of 5000 books.
# Info downloaded for book 607 of 5000 books.
# Info downloaded for book 608 of 5000 books.
# Info downloaded for book 609 of 5000 books.
# Info downloaded for book 610 of 5000 books.
# Info downloaded for book 611 of 5000 books.
# Info downloaded for book 612 of 5000 books.
# Info downloaded for book 613 of 5000 books.
# Info downloaded for book 614 of 5000 books.
# Info downloaded for book 615 of 5000 books.
# Info downloaded for book 616 of 5000 books.
# Info downloaded for book 617 of 5000 books.
# Info downloaded for book 618 of 5000 books.
# Info downloaded for book 619 of 5000 books.
# Info downloaded for book 620 of 5000 books.
# Info downloaded for book 621 of 5000 books.
# Info downloaded for book 622 of 5000 books.
# Info downloaded for book 623 of 5000 books.
# Info downloaded for book 624 of 5000 books.
# Info downloaded for book 625 of 5000 books.
# Info downloaded for book 626 of 5000 books.
# Info downloaded for book 627 of 5000 books.
# Info downloaded for book 628 of 5000 books.
# Info downloaded for book 629 of 5000 books.
# Info downloaded for book 630 of 5000 books.
# Info downloaded for book 631 of 5000 books.
# Info downloaded for book 632 of 5000 books.
# Info downloaded for book 633 of 5000 books.
# Info downloaded for book 634 of 5000 books.
# Info downloaded for book 635 of 5000 books.
# Info downloaded for book 636 of 5000 books.
# Info downloaded for book 637 of 5000 books.
# Info downloaded for book 638 of 5000 books.
# Info downloaded for book 639 of 5000 books.
# Info downloaded for book 640 of 5000 books.
# Info downloaded for book 641 of 5000 books.
# Info downloaded for book 642 of 5000 books.
# Info downloaded for book 643 of 5000 books.
# Info downloaded for book 644 of 5000 books.
# Info downloaded for book 645 of 5000 books.
# Info downloaded for book 646 of 5000 books.
# Info downloaded for book 647 of 5000 books.
# Info downloaded for book 648 of 5000 books.
# Info downloaded for book 649 of 5000 books.
# Info downloaded for book 650 of 5000 books.
# Info downloaded for book 651 of 5000 books.
# Info downloaded for book 652 of 5000 books.
# Info downloaded for book 653 of 5000 books.
# Info downloaded for book 654 of 5000 books.
# Info downloaded for book 655 of 5000 books.
# Info downloaded for book 656 of 5000 books.
# Info downloaded for book 657 of 5000 books.
# Info downloaded for book 658 of 5000 books.
# Info downloaded for book 659 of 5000 books.
# Info downloaded for book 660 of 5000 books.
# Info downloaded for book 661 of 5000 books.
# Info downloaded for book 662 of 5000 books.
# Info downloaded for book 663 of 5000 books.
# Info downloaded for book 664 of 5000 books.
# Info downloaded for book 665 of 5000 books.
# Info downloaded for book 666 of 5000 books.
# Info downloaded for book 667 of 5000 books.
# Info downloaded for book 668 of 5000 books.
# Info downloaded for book 669 of 5000 books.
# Info downloaded for book 670 of 5000 books.
# Info downloaded for book 671 of 5000 books.
# Info downloaded for book 672 of 5000 books.
# Info downloaded for book 673 of 5000 books.
# Info downloaded for book 674 of 5000 books.
# Info downloaded for book 675 of 5000 books.
# Info downloaded for book 676 of 5000 books.
# Info downloaded for book 677 of 5000 books.
# Info downloaded for book 678 of 5000 books.
# Info downloaded for book 679 of 5000 books.
# Info downloaded for book 680 of 5000 books.
# Info downloaded for book 681 of 5000 books.
# Info downloaded for book 682 of 5000 books.
# Info downloaded for book 683 of 5000 books.
# Info downloaded for book 684 of 5000 books.
# Info downloaded for book 685 of 5000 books.
# Info downloaded for book 686 of 5000 books.
# Info downloaded for book 687 of 5000 books.
# Info downloaded for book 688 of 5000 books.
# Info downloaded for book 689 of 5000 books.
# Info downloaded for book 690 of 5000 books.
# Info downloaded for book 691 of 5000 books.
# Info downloaded for book 692 of 5000 books.
# Info downloaded for book 693 of 5000 books.
# Info downloaded for book 694 of 5000 books.
# Info downloaded for book 695 of 5000 books.
# Info downloaded for book 696 of 5000 books.
# Info downloaded for book 697 of 5000 books.
# Info downloaded for book 698 of 5000 books.
# Info downloaded for book 699 of 5000 books.
# Info downloaded for book 700 of 5000 books.
# Info downloaded for book 701 of 5000 books.
# Info downloaded for book 702 of 5000 books.
# Info downloaded for book 703 of 5000 books.
# Info downloaded for book 704 of 5000 books.
# Info downloaded for book 705 of 5000 books.
# Info downloaded for book 706 of 5000 books.
# Info downloaded for book 707 of 5000 books.
# Info downloaded for book 708 of 5000 books.
# Info downloaded for book 709 of 5000 books.
# Info downloaded for book 710 of 5000 books.
# Info downloaded for book 711 of 5000 books.
# Info downloaded for book 712 of 5000 books.
# Info downloaded for book 713 of 5000 books.
# Info downloaded for book 714 of 5000 books.
# Info downloaded for book 715 of 5000 books.
# Info downloaded for book 716 of 5000 books.
# Info downloaded for book 717 of 5000 books.
# Info downloaded for book 718 of 5000 books.
# Info downloaded for book 719 of 5000 books.
# Info downloaded for book 720 of 5000 books.
# Info downloaded for book 721 of 5000 books.
# Info downloaded for book 722 of 5000 books.
# Info downloaded for book 723 of 5000 books.
# Info downloaded for book 724 of 5000 books.
# Info downloaded for book 725 of 5000 books.
# Info downloaded for book 726 of 5000 books.
# Info downloaded for book 727 of 5000 books.
# Info downloaded for book 728 of 5000 books.
# Info downloaded for book 729 of 5000 books.
# Info downloaded for book 730 of 5000 books.
# Info downloaded for book 731 of 5000 books.
# Info downloaded for book 732 of 5000 books.
# Info downloaded for book 733 of 5000 books.
# Info downloaded for book 734 of 5000 books.
# Info downloaded for book 735 of 5000 books.
# Info downloaded for book 736 of 5000 books.
# Info downloaded for book 737 of 5000 books.
# Info downloaded for book 738 of 5000 books.
# Info downloaded for book 739 of 5000 books.
# Info downloaded for book 740 of 5000 books.
# Info downloaded for book 741 of 5000 books.
# Info downloaded for book 742 of 5000 books.
# Info downloaded for book 743 of 5000 books.
# Info downloaded for book 744 of 5000 books.
# Info downloaded for book 745 of 5000 books.
# Info downloaded for book 746 of 5000 books.
# Info downloaded for book 747 of 5000 books.
# Info downloaded for book 748 of 5000 books.
# Info downloaded for book 749 of 5000 books.
# Info downloaded for book 750 of 5000 books.
# Info downloaded for book 751 of 5000 books.
# Info downloaded for book 752 of 5000 books.
# Info downloaded for book 753 of 5000 books.
# Info downloaded for book 754 of 5000 books.
# Info downloaded for book 755 of 5000 books.
# Info downloaded for book 756 of 5000 books.
# Info downloaded for book 757 of 5000 books.
# Info downloaded for book 758 of 5000 books.
# Info downloaded for book 759 of 5000 books.
# Info downloaded for book 760 of 5000 books.
# Info downloaded for book 761 of 5000 books.
# Info downloaded for book 762 of 5000 books.
# Info downloaded for book 763 of 5000 books.
# Info downloaded for book 764 of 5000 books.
# Info downloaded for book 765 of 5000 books.
# Info downloaded for book 766 of 5000 books.
# Info downloaded for book 767 of 5000 books.
# Info downloaded for book 768 of 5000 books.
# Info downloaded for book 769 of 5000 books.
# Info downloaded for book 770 of 5000 books.
# Info downloaded for book 771 of 5000 books.
# Info downloaded for book 772 of 5000 books.
# Info downloaded for book 773 of 5000 books.
# Info downloaded for book 774 of 5000 books.
# Info downloaded for book 775 of 5000 books.
# Info downloaded for book 776 of 5000 books.
# Info downloaded for book 777 of 5000 books.
# Info downloaded for book 778 of 5000 books.
# Info downloaded for book 779 of 5000 books.
# Info downloaded for book 780 of 5000 books.
# Info downloaded for book 781 of 5000 books.
# Info downloaded for book 782 of 5000 books.
# Info downloaded for book 783 of 5000 books.
# Info downloaded for book 784 of 5000 books.
# Info downloaded for book 785 of 5000 books.
# Info downloaded for book 786 of 5000 books.
# Info downloaded for book 787 of 5000 books.
# Info downloaded for book 788 of 5000 books.
# Info downloaded for book 789 of 5000 books.
# Info downloaded for book 790 of 5000 books.
# Info downloaded for book 791 of 5000 books.
# Info downloaded for book 792 of 5000 books.
# Info downloaded for book 793 of 5000 books.
# Info downloaded for book 794 of 5000 books.
# Info downloaded for book 795 of 5000 books.
# Info downloaded for book 796 of 5000 books.
# Info downloaded for book 797 of 5000 books.
# Info downloaded for book 798 of 5000 books.
# Info downloaded for book 799 of 5000 books.
# Info downloaded for book 800 of 5000 books.
# Info downloaded for book 801 of 5000 books.
# Info downloaded for book 802 of 5000 books.
# Info downloaded for book 803 of 5000 books.
# Info downloaded for book 804 of 5000 books.
# Info downloaded for book 805 of 5000 books.
# Info downloaded for book 806 of 5000 books.
# Info downloaded for book 807 of 5000 books.
# Info downloaded for book 808 of 5000 books.
# Info downloaded for book 809 of 5000 books.
# Info downloaded for book 810 of 5000 books.
# Info downloaded for book 811 of 5000 books.
# Info downloaded for book 812 of 5000 books.
# Info downloaded for book 813 of 5000 books.
# Info downloaded for book 814 of 5000 books.
# Info downloaded for book 815 of 5000 books.
# Info downloaded for book 816 of 5000 books.
# Info downloaded for book 817 of 5000 books.
# Info downloaded for book 818 of 5000 books.
# Info downloaded for book 819 of 5000 books.
# Info downloaded for book 820 of 5000 books.
# Info downloaded for book 821 of 5000 books.
# Info downloaded for book 822 of 5000 books.
# Info downloaded for book 823 of 5000 books.
# Info downloaded for book 824 of 5000 books.
# Info downloaded for book 825 of 5000 books.
# Info downloaded for book 826 of 5000 books.
# Info downloaded for book 827 of 5000 books.
# Info downloaded for book 828 of 5000 books.
# Info downloaded for book 829 of 5000 books.
# Info downloaded for book 830 of 5000 books.
# Info downloaded for book 831 of 5000 books.
# Info downloaded for book 832 of 5000 books.
# Info downloaded for book 833 of 5000 books.
# Info downloaded for book 834 of 5000 books.
# Info downloaded for book 835 of 5000 books.
# Info downloaded for book 836 of 5000 books.
# Info downloaded for book 837 of 5000 books.
# Info downloaded for book 838 of 5000 books.
# Info downloaded for book 839 of 5000 books.
# Info downloaded for book 840 of 5000 books.
# Info downloaded for book 841 of 5000 books.
# Info downloaded for book 842 of 5000 books.
# Info downloaded for book 843 of 5000 books.
# Info downloaded for book 844 of 5000 books.
# Info downloaded for book 845 of 5000 books.
# Info downloaded for book 846 of 5000 books.
# Info downloaded for book 847 of 5000 books.
# Info downloaded for book 848 of 5000 books.
# Info downloaded for book 849 of 5000 books.
# Info downloaded for book 850 of 5000 books.
# Info downloaded for book 851 of 5000 books.
# Info downloaded for book 852 of 5000 books.
# Info downloaded for book 853 of 5000 books.
# Info downloaded for book 854 of 5000 books.
# Info downloaded for book 855 of 5000 books.
# Info downloaded for book 856 of 5000 books.
# Info downloaded for book 857 of 5000 books.
# Info downloaded for book 858 of 5000 books.
# Info downloaded for book 859 of 5000 books.
# Info downloaded for book 860 of 5000 books.
# Info downloaded for book 861 of 5000 books.
# Info downloaded for book 862 of 5000 books.
# Info downloaded for book 863 of 5000 books.
# Info downloaded for book 864 of 5000 books.
# Info downloaded for book 865 of 5000 books.
# Info downloaded for book 866 of 5000 books.
# Info downloaded for book 867 of 5000 books.
# Info downloaded for book 868 of 5000 books.
# Info downloaded for book 869 of 5000 books.
# Info downloaded for book 870 of 5000 books.
# Info downloaded for book 871 of 5000 books.
# Info downloaded for book 872 of 5000 books.
# Info downloaded for book 873 of 5000 books.
# Info downloaded for book 874 of 5000 books.
# Info downloaded for book 875 of 5000 books.
# Info downloaded for book 876 of 5000 books.
# Info downloaded for book 877 of 5000 books.
# Info downloaded for book 878 of 5000 books.
# Info downloaded for book 879 of 5000 books.
# Info downloaded for book 880 of 5000 books.
# Info downloaded for book 881 of 5000 books.
# Info downloaded for book 882 of 5000 books.
# Info downloaded for book 883 of 5000 books.
# Info downloaded for book 884 of 5000 books.
# Info downloaded for book 885 of 5000 books.
# Info downloaded for book 886 of 5000 books.
# Info downloaded for book 887 of 5000 books.
# Info downloaded for book 888 of 5000 books.
# Info downloaded for book 889 of 5000 books.
# Info downloaded for book 890 of 5000 books.
# Info downloaded for book 891 of 5000 books.
# Info downloaded for book 892 of 5000 books.
# Info downloaded for book 893 of 5000 books.
# Info downloaded for book 894 of 5000 books.
# Info downloaded for book 895 of 5000 books.
# Info downloaded for book 896 of 5000 books.
# Info downloaded for book 897 of 5000 books.
# Info downloaded for book 898 of 5000 books.
# Info downloaded for book 899 of 5000 books.
# Info downloaded for book 900 of 5000 books.
# Info downloaded for book 901 of 5000 books.
# Info downloaded for book 902 of 5000 books.
# Info downloaded for book 903 of 5000 books.
# Info downloaded for book 904 of 5000 books.
# Info downloaded for book 905 of 5000 books.
# Info downloaded for book 906 of 5000 books.
# Info downloaded for book 907 of 5000 books.
# Info downloaded for book 908 of 5000 books.
# Info downloaded for book 909 of 5000 books.
# Info downloaded for book 910 of 5000 books.
# Info downloaded for book 911 of 5000 books.
# Info downloaded for book 912 of 5000 books.
# Info downloaded for book 913 of 5000 books.
# Info downloaded for book 914 of 5000 books.
# Info downloaded for book 915 of 5000 books.
# Info downloaded for book 916 of 5000 books.
# Info downloaded for book 917 of 5000 books.
# Info downloaded for book 918 of 5000 books.
# Info downloaded for book 919 of 5000 books.
# Info downloaded for book 920 of 5000 books.
# Info downloaded for book 921 of 5000 books.
# Info downloaded for book 922 of 5000 books.
# Info downloaded for book 923 of 5000 books.
# Info downloaded for book 924 of 5000 books.
# Info downloaded for book 925 of 5000 books.
# Info downloaded for book 926 of 5000 books.
# Info downloaded for book 927 of 5000 books.
# Info downloaded for book 928 of 5000 books.
# Info downloaded for book 929 of 5000 books.
# Info downloaded for book 930 of 5000 books.
# Info downloaded for book 931 of 5000 books.
# Info downloaded for book 932 of 5000 books.
# Info downloaded for book 933 of 5000 books.
# Info downloaded for book 934 of 5000 books.
# Info downloaded for book 935 of 5000 books.
# Info downloaded for book 936 of 5000 books.
# Info downloaded for book 937 of 5000 books.
# Info downloaded for book 938 of 5000 books.
# Info downloaded for book 939 of 5000 books.
# Info downloaded for book 940 of 5000 books.
# Info downloaded for book 941 of 5000 books.
# Info downloaded for book 942 of 5000 books.
# Info downloaded for book 943 of 5000 books.
# Info downloaded for book 944 of 5000 books.
# Info downloaded for book 945 of 5000 books.
# Info downloaded for book 946 of 5000 books.
# Info downloaded for book 947 of 5000 books.
# Info downloaded for book 948 of 5000 books.
# Info downloaded for book 949 of 5000 books.
# Info downloaded for book 950 of 5000 books.
# Info downloaded for book 951 of 5000 books.
# Info downloaded for book 952 of 5000 books.
# Info downloaded for book 953 of 5000 books.
# Info downloaded for book 954 of 5000 books.
# Info downloaded for book 955 of 5000 books.
# Info downloaded for book 956 of 5000 books.
# Info downloaded for book 957 of 5000 books.
# Info downloaded for book 958 of 5000 books.
# Info downloaded for book 959 of 5000 books.
# Info downloaded for book 960 of 5000 books.
# Info downloaded for book 961 of 5000 books.
# Info downloaded for book 962 of 5000 books.
# Info downloaded for book 963 of 5000 books.
# Info downloaded for book 964 of 5000 books.
# Info downloaded for book 965 of 5000 books.
# Info downloaded for book 966 of 5000 books.
# Info downloaded for book 967 of 5000 books.
# Info downloaded for book 968 of 5000 books.
# Info downloaded for book 969 of 5000 books.
# Info downloaded for book 970 of 5000 books.
# Info downloaded for book 971 of 5000 books.
# Info downloaded for book 972 of 5000 books.
# Info downloaded for book 973 of 5000 books.
# Info downloaded for book 974 of 5000 books.
# Info downloaded for book 975 of 5000 books.
# Info downloaded for book 976 of 5000 books.
# Info downloaded for book 977 of 5000 books.
# Info downloaded for book 978 of 5000 books.
# Info downloaded for book 979 of 5000 books.
# Info downloaded for book 980 of 5000 books.
# Info downloaded for book 981 of 5000 books.
# Info downloaded for book 982 of 5000 books.
# Info downloaded for book 983 of 5000 books.
# Info downloaded for book 984 of 5000 books.
# Info downloaded for book 985 of 5000 books.
# Info downloaded for book 986 of 5000 books.
# Info downloaded for book 987 of 5000 books.
# Info downloaded for book 988 of 5000 books.
# Info downloaded for book 989 of 5000 books.
# Info downloaded for book 990 of 5000 books.
# Info downloaded for book 991 of 5000 books.
# Info downloaded for book 992 of 5000 books.
# Info downloaded for book 993 of 5000 books.
# Info downloaded for book 994 of 5000 books.
# Info downloaded for book 995 of 5000 books.
# Info downloaded for book 996 of 5000 books.
# Info downloaded for book 997 of 5000 books.
# Info downloaded for book 998 of 5000 books.
# Info downloaded for book 999 of 5000 books.
# Info downloaded for book 1000 of 5000 books.
# Info downloaded for book 1001 of 5000 books.
# Info downloaded for book 1002 of 5000 books.
# Info downloaded for book 1003 of 5000 books.
# Info downloaded for book 1004 of 5000 books.
# Info downloaded for book 1005 of 5000 books.
# Info downloaded for book 1006 of 5000 books.
# Info downloaded for book 1007 of 5000 books.
# Info downloaded for book 1008 of 5000 books.
# Info downloaded for book 1009 of 5000 books.
# Info downloaded for book 1010 of 5000 books.
# Info downloaded for book 1011 of 5000 books.
# Info downloaded for book 1012 of 5000 books.
# Info downloaded for book 1013 of 5000 books.
# Info downloaded for book 1014 of 5000 books.
# Info downloaded for book 1015 of 5000 books.
# Info downloaded for book 1016 of 5000 books.
# Info downloaded for book 1017 of 5000 books.
# Info downloaded for book 1018 of 5000 books.
# Info downloaded for book 1019 of 5000 books.
# Info downloaded for book 1020 of 5000 books.
# Info downloaded for book 1021 of 5000 books.
# Info downloaded for book 1022 of 5000 books.
# Info downloaded for book 1023 of 5000 books.
# Info downloaded for book 1024 of 5000 books.
# Info downloaded for book 1025 of 5000 books.
# Info downloaded for book 1026 of 5000 books.
# Info downloaded for book 1027 of 5000 books.
# Info downloaded for book 1028 of 5000 books.
# Info downloaded for book 1029 of 5000 books.
# Info downloaded for book 1030 of 5000 books.
# Info downloaded for book 1031 of 5000 books.
# Info downloaded for book 1032 of 5000 books.
# Info downloaded for book 1033 of 5000 books.
# Info downloaded for book 1034 of 5000 books.
# Info downloaded for book 1035 of 5000 books.
# Info downloaded for book 1036 of 5000 books.
# Info downloaded for book 1037 of 5000 books.
# Info downloaded for book 1038 of 5000 books.
# Info downloaded for book 1039 of 5000 books.
# Info downloaded for book 1040 of 5000 books.
# Info downloaded for book 1041 of 5000 books.
# Info downloaded for book 1042 of 5000 books.
# Info downloaded for book 1043 of 5000 books.
# Info downloaded for book 1044 of 5000 books.
# Info downloaded for book 1045 of 5000 books.
# Info downloaded for book 1046 of 5000 books.
# Info downloaded for book 1047 of 5000 books.
# Info downloaded for book 1048 of 5000 books.
# Info downloaded for book 1049 of 5000 books.
# Info downloaded for book 1050 of 5000 books.
# Info downloaded for book 1051 of 5000 books.
# Info downloaded for book 1052 of 5000 books.
# Info downloaded for book 1053 of 5000 books.
# Info downloaded for book 1054 of 5000 books.
# Info downloaded for book 1055 of 5000 books.
# Info downloaded for book 1056 of 5000 books.
# Info downloaded for book 1057 of 5000 books.
# Info downloaded for book 1058 of 5000 books.
# Info downloaded for book 1059 of 5000 books.
# Info downloaded for book 1060 of 5000 books.
# Info downloaded for book 1061 of 5000 books.
# Info downloaded for book 1062 of 5000 books.
# Info downloaded for book 1063 of 5000 books.
# Info downloaded for book 1064 of 5000 books.
# Info downloaded for book 1065 of 5000 books.
# Info downloaded for book 1066 of 5000 books.
# Info downloaded for book 1067 of 5000 books.
# Info downloaded for book 1068 of 5000 books.
# Info downloaded for book 1069 of 5000 books.
# Info downloaded for book 1070 of 5000 books.
# Info downloaded for book 1071 of 5000 books.
# Info downloaded for book 1072 of 5000 books.
# Info downloaded for book 1073 of 5000 books.
# Info downloaded for book 1074 of 5000 books.
# Info downloaded for book 1075 of 5000 books.
# Info downloaded for book 1076 of 5000 books.
# Info downloaded for book 1077 of 5000 books.
# Info downloaded for book 1078 of 5000 books.
# Info downloaded for book 1079 of 5000 books.
# Info downloaded for book 1080 of 5000 books.
# Info downloaded for book 1081 of 5000 books.
# Info downloaded for book 1082 of 5000 books.
# Info downloaded for book 1083 of 5000 books.
# Info downloaded for book 1084 of 5000 books.
# Info downloaded for book 1085 of 5000 books.
# Info downloaded for book 1086 of 5000 books.
# Info downloaded for book 1087 of 5000 books.
# Info downloaded for book 1088 of 5000 books.
# Info downloaded for book 1089 of 5000 books.
# Info downloaded for book 1090 of 5000 books.
# Info downloaded for book 1091 of 5000 books.
# ...
# Info downloaded for book 4646 of 5000 books.
# Info downloaded for book 4647 of 5000 books.
# Info downloaded for book 4648 of 5000 books.
# Info downloaded for book 4649 of 5000 books.
# Info downloaded for book 4650 of 5000 books.
# Info downloaded for book 4651 of 5000 books.
# Info downloaded for book 4652 of 5000 books.
# Info downloaded for book 4653 of 5000 books.
# Info downloaded for book 4654 of 5000 books.
# Info downloaded for book 4655 of 5000 books.
# Info downloaded for book 4656 of 5000 books.
# Info downloaded for book 4657 of 5000 books.
# Info downloaded for book 4658 of 5000 books.
# Info downloaded for book 4659 of 5000 books.
# Info downloaded for book 4660 of 5000 books.
# Info downloaded for book 4661 of 5000 books.
# Info downloaded for book 4662 of 5000 books.
# Info downloaded for book 4663 of 5000 books.
# Info downloaded for book 4664 of 5000 books.
# Info downloaded for book 4665 of 5000 books.
# Info downloaded for book 4666 of 5000 books.
# Info downloaded for book 4667 of 5000 books.
# Info downloaded for book 4668 of 5000 books.
# Info downloaded for book 4669 of 5000 books.
# Info downloaded for book 4670 of 5000 books.
# Info downloaded for book 4671 of 5000 books.
# Info downloaded for book 4672 of 5000 books.
# Info downloaded for book 4673 of 5000 books.
# Info downloaded for book 4674 of 5000 books.
# Info downloaded for book 4675 of 5000 books.
# Info downloaded for book 4676 of 5000 books.
# Info downloaded for book 4677 of 5000 books.
# Info downloaded for book 4678 of 5000 books.
# Info downloaded for book 4679 of 5000 books.
# Info downloaded for book 4680 of 5000 books.
# Info downloaded for book 4681 of 5000 books.
# Info downloaded for book 4682 of 5000 books.
# Info downloaded for book 4683 of 5000 books.
# Info downloaded for book 4684 of 5000 books.
# Info downloaded for book 4685 of 5000 books.
# Info downloaded for book 4686 of 5000 books.
# Info downloaded for book 4687 of 5000 books.
# Info downloaded for book 4688 of 5000 books.
# Info downloaded for book 4689 of 5000 books.
# Info downloaded for book 4690 of 5000 books.
# Info downloaded for book 4691 of 5000 books.
# Info downloaded for book 4692 of 5000 books.
# Info downloaded for book 4693 of 5000 books.
# Info downloaded for book 4694 of 5000 books.
# Info downloaded for book 4695 of 5000 books.
# Info downloaded for book 4696 of 5000 books.
# Info downloaded for book 4697 of 5000 books.
# Info downloaded for book 4698 of 5000 books.
# Info downloaded for book 4699 of 5000 books.
# Info downloaded for book 4700 of 5000 books.
# Info downloaded for book 4701 of 5000 books.
# Info downloaded for book 4702 of 5000 books.
# Info downloaded for book 4703 of 5000 books.
# Info downloaded for book 4704 of 5000 books.
# Info downloaded for book 4705 of 5000 books.
# Info downloaded for book 4706 of 5000 books.
# Info downloaded for book 4707 of 5000 books.
# Info downloaded for book 4708 of 5000 books.
# Info downloaded for book 4709 of 5000 books.
# Info downloaded for book 4710 of 5000 books.
# Info downloaded for book 4711 of 5000 books.
# Info downloaded for book 4712 of 5000 books.
# Info downloaded for book 4713 of 5000 books.
# Info downloaded for book 4714 of 5000 books.
# Info downloaded for book 4715 of 5000 books.
# Info downloaded for book 4716 of 5000 books.
# Info downloaded for book 4717 of 5000 books.
# Info downloaded for book 4718 of 5000 books.
# Info downloaded for book 4719 of 5000 books.
# Info downloaded for book 4720 of 5000 books.
# Info downloaded for book 4721 of 5000 books.
# Info downloaded for book 4722 of 5000 books.
# Info downloaded for book 4723 of 5000 books.
# Info downloaded for book 4724 of 5000 books.
# Info downloaded for book 4725 of 5000 books.
# Info downloaded for book 4726 of 5000 books.
# Info downloaded for book 4727 of 5000 books.
# Info downloaded for book 4728 of 5000 books.
# Info downloaded for book 4729 of 5000 books.
# Info downloaded for book 4730 of 5000 books.
# Info downloaded for book 4731 of 5000 books.
# Info downloaded for book 4732 of 5000 books.
# Info downloaded for book 4733 of 5000 books.
# Info downloaded for book 4734 of 5000 books.
# Info downloaded for book 4735 of 5000 books.
# Info downloaded for book 4736 of 5000 books.
# Info downloaded for book 4737 of 5000 books.
# Info downloaded for book 4738 of 5000 books.
# Info downloaded for book 4739 of 5000 books.
# Info downloaded for book 4740 of 5000 books.
# Info downloaded for book 4741 of 5000 books.
# Info downloaded for book 4742 of 5000 books.
# Info downloaded for book 4743 of 5000 books.
# Info downloaded for book 4744 of 5000 books.
# Info downloaded for book 4745 of 5000 books.
# Info downloaded for book 4746 of 5000 books.
# Info downloaded for book 4747 of 5000 books.
# Info downloaded for book 4748 of 5000 books.
# Info downloaded for book 4749 of 5000 books.
# Info downloaded for book 4750 of 5000 books.
# Info downloaded for book 4751 of 5000 books.
# Info downloaded for book 4752 of 5000 books.
# Info downloaded for book 4753 of 5000 books.
# Info downloaded for book 4754 of 5000 books.
# Info downloaded for book 4755 of 5000 books.
# Info downloaded for book 4756 of 5000 books.
# Info downloaded for book 4757 of 5000 books.
# Info downloaded for book 4758 of 5000 books.
# Info downloaded for book 4759 of 5000 books.
# Info downloaded for book 4760 of 5000 books.
# Info downloaded for book 4761 of 5000 books.
# Info downloaded for book 4762 of 5000 books.
# Info downloaded for book 4763 of 5000 books.
# Info downloaded for book 4764 of 5000 books.
# Info downloaded for book 4765 of 5000 books.
# Info downloaded for book 4766 of 5000 books.
# Info downloaded for book 4767 of 5000 books.
# Info downloaded for book 4768 of 5000 books.
# Info downloaded for book 4769 of 5000 books.
# Info downloaded for book 4770 of 5000 books.
# Info downloaded for book 4771 of 5000 books.
# Info downloaded for book 4772 of 5000 books.
# Info downloaded for book 4773 of 5000 books.
# Info downloaded for book 4774 of 5000 books.
# Info downloaded for book 4775 of 5000 books.
# Info downloaded for book 4776 of 5000 books.
# Info downloaded for book 4777 of 5000 books.
# Info downloaded for book 4778 of 5000 books.
# Info downloaded for book 4779 of 5000 books.
# Info downloaded for book 4780 of 5000 books.
# Info downloaded for book 4781 of 5000 books.
# Info downloaded for book 4782 of 5000 books.
# Info downloaded for book 4783 of 5000 books.
# Info downloaded for book 4784 of 5000 books.
# Info downloaded for book 4785 of 5000 books.
# Info downloaded for book 4786 of 5000 books.
# Info downloaded for book 4787 of 5000 books.
# Info downloaded for book 4788 of 5000 books.
# Info downloaded for book 4789 of 5000 books.
# Info downloaded for book 4790 of 5000 books.
# Info downloaded for book 4791 of 5000 books.
# Info downloaded for book 4792 of 5000 books.
# Info downloaded for book 4793 of 5000 books.
# Info downloaded for book 4794 of 5000 books.
# Info downloaded for book 4795 of 5000 books.
# Info downloaded for book 4796 of 5000 books.
# Info downloaded for book 4797 of 5000 books.
# Info downloaded for book 4798 of 5000 books.
# Info downloaded for book 4799 of 5000 books.
# Info downloaded for book 4800 of 5000 books.
# Info downloaded for book 4801 of 5000 books.
# Info downloaded for book 4802 of 5000 books.
# Info downloaded for book 4803 of 5000 books.
# Info downloaded for book 4804 of 5000 books.
# Info downloaded for book 4805 of 5000 books.
# Info downloaded for book 4806 of 5000 books.
# Info downloaded for book 4807 of 5000 books.
# Info downloaded for book 4808 of 5000 books.
# Info downloaded for book 4809 of 5000 books.
# Info downloaded for book 4810 of 5000 books.
# Info downloaded for book 4811 of 5000 books.
# Info downloaded for book 4812 of 5000 books.
# Info downloaded for book 4813 of 5000 books.
# Info downloaded for book 4814 of 5000 books.
# Info downloaded for book 4815 of 5000 books.
# Info downloaded for book 4816 of 5000 books.
# Info downloaded for book 4817 of 5000 books.
# Info downloaded for book 4818 of 5000 books.
# Info downloaded for book 4819 of 5000 books.
# Info downloaded for book 4820 of 5000 books.
# Info downloaded for book 4821 of 5000 books.
# Info downloaded for book 4822 of 5000 books.
# Info downloaded for book 4823 of 5000 books.
# Info downloaded for book 4824 of 5000 books.
# Info downloaded for book 4825 of 5000 books.
# Info downloaded for book 4826 of 5000 books.
# Info downloaded for book 4827 of 5000 books.
# Info downloaded for book 4828 of 5000 books.
# Info downloaded for book 4829 of 5000 books.
# Info downloaded for book 4830 of 5000 books.
# Info downloaded for book 4831 of 5000 books.
# Info downloaded for book 4832 of 5000 books.
# Info downloaded for book 4833 of 5000 books.
# Info downloaded for book 4834 of 5000 books.
# Info downloaded for book 4835 of 5000 books.
# Info downloaded for book 4836 of 5000 books.
# Info downloaded for book 4837 of 5000 books.
# Info downloaded for book 4838 of 5000 books.
# Info downloaded for book 4839 of 5000 books.
# Info downloaded for book 4840 of 5000 books.
# Info downloaded for book 4841 of 5000 books.
# Info downloaded for book 4842 of 5000 books.
# Info downloaded for book 4843 of 5000 books.
# Info downloaded for book 4844 of 5000 books.
# Info downloaded for book 4845 of 5000 books.
# Info downloaded for book 4846 of 5000 books.
# Info downloaded for book 4847 of 5000 books.
# Info downloaded for book 4848 of 5000 books.
# Info downloaded for book 4849 of 5000 books.
# Info downloaded for book 4850 of 5000 books.
# Info downloaded for book 4851 of 5000 books.
# Info downloaded for book 4852 of 5000 books.
# Info downloaded for book 4853 of 5000 books.
# Info downloaded for book 4854 of 5000 books.
# Info downloaded for book 4855 of 5000 books.
# Info downloaded for book 4856 of 5000 books.
# Info downloaded for book 4857 of 5000 books.
# Info downloaded for book 4858 of 5000 books.
# Info downloaded for book 4859 of 5000 books.
# Info downloaded for book 4860 of 5000 books.
# Info downloaded for book 4861 of 5000 books.
# Info downloaded for book 4862 of 5000 books.
# Info downloaded for book 4863 of 5000 books.
# Info downloaded for book 4864 of 5000 books.
# Info downloaded for book 4865 of 5000 books.
# Info downloaded for book 4866 of 5000 books.
# Info downloaded for book 4867 of 5000 books.
# Info downloaded for book 4868 of 5000 books.
# Info downloaded for book 4869 of 5000 books.
# Info downloaded for book 4870 of 5000 books.
# Info downloaded for book 4871 of 5000 books.
# Info downloaded for book 4872 of 5000 books.
# Info downloaded for book 4873 of 5000 books.
# Info downloaded for book 4874 of 5000 books.
# Info downloaded for book 4875 of 5000 books.
# Info downloaded for book 4876 of 5000 books.
# Info downloaded for book 4877 of 5000 books.
# Info downloaded for book 4878 of 5000 books.
# Info downloaded for book 4879 of 5000 books.
# Info downloaded for book 4880 of 5000 books.
# Info downloaded for book 4881 of 5000 books.
# Info downloaded for book 4882 of 5000 books.
# Info downloaded for book 4883 of 5000 books.
# Info downloaded for book 4884 of 5000 books.
# Info downloaded for book 4885 of 5000 books.
# Info downloaded for book 4886 of 5000 books.
# Info downloaded for book 4887 of 5000 books.
# Info downloaded for book 4888 of 5000 books.
# Info downloaded for book 4889 of 5000 books.
# Info downloaded for book 4890 of 5000 books.
# Info downloaded for book 4891 of 5000 books.
# Info downloaded for book 4892 of 5000 books.
# Info downloaded for book 4893 of 5000 books.
# Info downloaded for book 4894 of 5000 books.
# Info downloaded for book 4895 of 5000 books.
# Info downloaded for book 4896 of 5000 books.
# Info downloaded for book 4897 of 5000 books.
# Info downloaded for book 4898 of 5000 books.
# Info downloaded for book 4899 of 5000 books.
# Info downloaded for book 4900 of 5000 books.
# Info downloaded for book 4901 of 5000 books.
# Info downloaded for book 4902 of 5000 books.
# Info downloaded for book 4903 of 5000 books.
# Info downloaded for book 4904 of 5000 books.
# Info downloaded for book 4905 of 5000 books.
# Info downloaded for book 4906 of 5000 books.
# Info downloaded for book 4907 of 5000 books.
# Info downloaded for book 4908 of 5000 books.
# Info downloaded for book 4909 of 5000 books.
# Info downloaded for book 4910 of 5000 books.
# Info downloaded for book 4911 of 5000 books.
# Info downloaded for book 4912 of 5000 books.
# Info downloaded for book 4913 of 5000 books.
# Info downloaded for book 4914 of 5000 books.
# Info downloaded for book 4915 of 5000 books.
# Info downloaded for book 4916 of 5000 books.
# Info downloaded for book 4917 of 5000 books.
# Info downloaded for book 4918 of 5000 books.
# Info downloaded for book 4919 of 5000 books.
# Info downloaded for book 4920 of 5000 books.
# Info downloaded for book 4921 of 5000 books.
# Info downloaded for book 4922 of 5000 books.
# Info downloaded for book 4923 of 5000 books.
# Info downloaded for book 4924 of 5000 books.
# Info downloaded for book 4925 of 5000 books.
# Info downloaded for book 4926 of 5000 books.
# Info downloaded for book 4927 of 5000 books.
# Info downloaded for book 4928 of 5000 books.
# Info downloaded for book 4929 of 5000 books.
# Info downloaded for book 4930 of 5000 books.
# Info downloaded for book 4931 of 5000 books.
# Info downloaded for book 4932 of 5000 books.
# Info downloaded for book 4933 of 5000 books.
# Info downloaded for book 4934 of 5000 books.
# Info downloaded for book 4935 of 5000 books.
# Info downloaded for book 4936 of 5000 books.
# Info downloaded for book 4937 of 5000 books.
# Info downloaded for book 4938 of 5000 books.
# Info downloaded for book 4939 of 5000 books.
# Info downloaded for book 4940 of 5000 books.
# Info downloaded for book 4941 of 5000 books.
# Info downloaded for book 4942 of 5000 books.
# Info downloaded for book 4943 of 5000 books.
# Info downloaded for book 4944 of 5000 books.
# Info downloaded for book 4945 of 5000 books.
# Info downloaded for book 4946 of 5000 books.
# Info downloaded for book 4947 of 5000 books.
# Info downloaded for book 4948 of 5000 books.
# Info downloaded for book 4949 of 5000 books.
# Info downloaded for book 4950 of 5000 books.
# Info downloaded for book 4951 of 5000 books.
# Info downloaded for book 4952 of 5000 books.
# Info downloaded for book 4953 of 5000 books.
# Info downloaded for book 4954 of 5000 books.
# Info downloaded for book 4955 of 5000 books.
# Info downloaded for book 4956 of 5000 books.
# Info downloaded for book 4957 of 5000 books.
# Info downloaded for book 4958 of 5000 books.
# Info downloaded for book 4959 of 5000 books.
# Info downloaded for book 4960 of 5000 books.
# Info downloaded for book 4961 of 5000 books.
# Info downloaded for book 4962 of 5000 books.
# Info downloaded for book 4963 of 5000 books.
# Info downloaded for book 4964 of 5000 books.
# Info downloaded for book 4965 of 5000 books.
# Info downloaded for book 4966 of 5000 books.
# Info downloaded for book 4967 of 5000 books.
# Info downloaded for book 4968 of 5000 books.
# Info downloaded for book 4969 of 5000 books.
# Info downloaded for book 4970 of 5000 books.
# Info downloaded for book 4971 of 5000 books.
# Info downloaded for book 4972 of 5000 books.
# Info downloaded for book 4973 of 5000 books.
# Info downloaded for book 4974 of 5000 books.
# Info downloaded for book 4975 of 5000 books.
# Info downloaded for book 4976 of 5000 books.
# Info downloaded for book 4977 of 5000 books.
# Info downloaded for book 4978 of 5000 books.
# Info downloaded for book 4979 of 5000 books.
# Info downloaded for book 4980 of 5000 books.
# Info downloaded for book 4981 of 5000 books.
# Info downloaded for book 4982 of 5000 books.
# Info downloaded for book 4983 of 5000 books.
# Info downloaded for book 4984 of 5000 books.
# Info downloaded for book 4985 of 5000 books.
# Info downloaded for book 4986 of 5000 books.
# Info downloaded for book 4987 of 5000 books.
# Info downloaded for book 4988 of 5000 books.
# Info downloaded for book 4989 of 5000 books.
# Info downloaded for book 4990 of 5000 books.
# Info downloaded for book 4991 of 5000 books.
# Info downloaded for book 4992 of 5000 books.
# Info downloaded for book 4993 of 5000 books.
# Info downloaded for book 4994 of 5000 books.
# Info downloaded for book 4995 of 5000 books.
# Info downloaded for book 4996 of 5000 books.
# Info downloaded for book 4997 of 5000 books.
# Info downloaded for book 4998 of 5000 books.
# Info downloaded for book 4999 of 5000 books.
# Info downloaded for book 5000 of 5000 books.

# %%
now = datetime.now()
dt = now.strftime("%d-%m-%Y_%H-%M-%S")

isbn.to_csv('../data/saved/isbn' + dt +'.csv', index = False)

# %% [markdown]
# ### EDA

# %%
# df download_jpg(url, file_path, file_name):
#     full_path = file_path + file_name + '.jpg'
#     urllib.request.urlretrieve(url, full_path)
    
# url =
# file_name = 'https://images.isbndb.com/covers/94/86/9781934759486.jpg'

# %% [markdown]
# ### Canadian

# %%
canadian = pd.read_csv('../data/processed/canadian_processed.csv')

# %%
canadian.dtypes
# Out:
# isbn            object
# title           object
# author          object
# Unnamed: 3     float64
# description     object
# dtype: object

# %%
canadian.drop(columns=['Unnamed: 3'], inplace = True)

# %%
canadian.shape
# Out:
# (205, 4)

# %%
canadian.head(40)
# Out:
#              isbn                                         title  \
# 0   9780773524927                                 Two Solitudes
# 1   9781552453056                                  Fifteen Dogs
# 2   9780771030130                                          Bear
# 3   9781554685257                    Green Grass, Running Water
# 4   9780771055706                             No Great Mischief
# 5   9780312054366                                  Generation X
# 6   9780676977738                               The Birth House
# 7   9780062468475                Lullabies for Little Criminals
# 8   9780006393108                                    Lost Girls
# 9   9781443451352                                        Birdie
# 10  9780307357281                             The Stone Diaries
# 11  9780441007462                                   Neuromancer
# 12  9780751547382                                    Still Life
# 13  9780451528827                          Anne of Green Gables
# 14  9781487005375                          The Sisters Brothers
# 15  9780676973228                                  Monkey Beach
# 16  9780385663175                                     Sweetland
# 17  9780143194798              13 Ways of Looking at a Fat Girl
# 18  9780394280134                           The English Patient
# 19  9780771038129                            Late Nights on Air
# 20  9780771058820                               Fugitive Pieces
# 21  9780887849626                                      February
# 22  9780586090398  By Grand Central Station I Sat Down and Wept
# 23  9780676972153               The Colony of Unrequited Dreams
# 24  9780143187424                     A Tale for the Time Being
# 25  9780857865540                                    Life of Pi
# 26  9780007156283                                  The Romantic
# 27  9780062262837                           The Secret Daughter
# 28  9781443434874                                Station Eleven
# 29  9781982147181                             The Kitchen House
# 30  9782764804636                                            Ru
# 31  9781553654025                                  Indian Horse
# 32  9780676973600                               The Hero's Walk
# 33  9780312573577                                 Still Missing
# 34  9780802123367                                          Tell
# 35  9781443433471                              Half-blood Blues
# 36  9780771008795                           The Handmaid's Tale
# 37  9780446674331                        Brown Girl in the Ring
# 38  9780771060540                                A Fine Balance
# 39  9780394281780                            Fall on Your Knees
#
#                   author                                        description
# 0          Hugh McLennan  “[A] powerful saga, [Two Solitudes is the stor...
# 1           Andre Alexis  “A bet between the gods Hermes and Apollo lead...
# 2           Marian Engel  “A librarian is called to a remote Canadian is...
# 3            Thomas King  “Alberta is a university professor who would l...
# 4       Alistair MacLeod  “Alexander, orphaned as a child by a horrific ...
# 5       Douglas Coupland  “Andy, Dag and Claire have been handed a socie...
# 6              Ami McKay  “As a child in an isolated village in Nova Sco...
# 7        Heather O'Neill  “At thirteen, Baby vacillates between childhoo...
# 8           Andrew Pyper  “Attorney Bartholomew Crane doesn’t belong in ...
# 9        Tracey Lindberg  “Bernice Meetoos, a Cree woman, leaves her hom...
# 10         Carol Shields  “Born in 1905, Daisy Stone Goodwill drifts thr...
# 11        William Gibson  “Case had been the sharpest data-thief in the ...
# 12          Louise Penny  “Chief Inspector Armand Gamache of the Sûreté ...
# 13  Lucy Maud Montgomery  “Everyone’s favorite redhead, the spunky Anne ...
# 14        Patrick deWitt  “Filled with a remarkable cast of characters –...
# 15         Eden Robinson  “Five hundred miles north of Vancouver is Kita...
# 16       Michael Crummey  “For twelve generations, when the fish were pl...
# 17             Mona Awad  “Growing up in the suburban hell of Misery Sag...
# 18      Michael Ondaatje  “Hana, the exhausted nurse; the maimed thief, ...
# 19         Elizabeth Hay  “Harry Boyd, a hard-bitten refugee from failur...
# 20         Anne Michaels  “In 1940 a boy bursts from the mud of a war-to...
# 21            Lisa Moore  “In 1982, the oil rig Ocean Ranger sank off th...
# 22       Elizabeth Smart  “In lushly evocative language, Smart recounts ...
# 23         Wayne Johnson  “In this widely acclaimed novel, Johnston has ...
# 24            Ruth Ozeki  “In Tokyo, sixteen-year-old Nao has decided th...
# 25           Yann Martel  “Life of Pi is a fantasy adventure novel by Ya...
# 26         Barbara Gowdy  “Louise Kirk learns about love and loss at an ...
# 27   Shilpi Somaya Gowda  “On the eve of the monsoons, in a remote India...
# 28  Emily St John Mandel  “One snowy night a famous Hollywood actor slum...
# 29      Kathleen Grissom  “Orphaned while onboard ship from Ireland, sev...
# 30              Kim Thuy  “Ru. In Vietnamese it means lullaby; in French...
# 31      Richard Wagamese  “Saul Indian Horse has hit bottom. His last bi...
# 32      Anita Rau Badami  “Set in the dusty seaside town of Toturpuram o...
# 33         Chevy Stevens  “Still Missing interweaves the year Annie spen...
# 34         Frances Itani  “Tell…  follows Tress’s partner Kenan, a young...
# 35           Esi Edugyan  “The aftermath of the fall of Paris, 1940. Hie...
# 36       Margaret Atwood  “The Republic of Gilead offers Offred only one...
# 37        Nalo Hopkinson  “The rich and privileged have fled the city, b...
# 38       Rohinton Mistry  “The time is 1975. The place is an unnamed cit...
# 39   Ann Marie MacDonald  “They are the Pipers of Cape Breton Island — a...

# %% [markdown]
# ### International

# %% [markdown]
# ### Content accumulation

# %%
international = pd.read_csv('../data/processed/international_processed.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 12: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-f5d24537746d> in <module>
# ----> 1 international = pd.read_csv('../data/processed/international_processed.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 12: invalid start byte

# %%
# isbn = pd.read_csv('../data/isbnlist.csv', 'isbn' : str)
# base_url = 'https://www.biblioshare.ca/BNCServices/BNCServices.asmx/ONIX?Token=zvo3vpz7uulcuajs&EAN='
# for isbn in isbn['isbn']:
#     target_url = base_url + isbn

# %% [markdown]
# ### Preprocessing

# %%
# Preprocess the posting content; this should take under 2 minutes
# start an empty list to hold preprocessed postings

for i in range(len(df)):  # for each description
    desc = re.sub('[^a-zA-Z]', ' ', df['description'][i]) # remove non text characters
    desc = desc.lower() # lower-case everything
    desc = desc.split() # split into words
    desc = ' '.join(desc) # reassemble the string
    df['description'][i] = desc

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### TF-IDF

# %%
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 3), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['description'])
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %% [markdown]
# ### Recommender

# %%
results = {}

for idx, row in df.iterrows():
    similar_indices = cosine_similarities[idx].argsort()[:-100:-1]
    similar_items = [(cosine_similarities[idx][i], df['id'][i]) for i in similar_indices]
    results[row['id']] = similar_items[1:]

# %%
def item(id):
    return df.loc[df['id'] == id]['description'].tolist()[0].split(' - ')[0]

# %%
def recommend(item_id, num):
    print("Here " + str(num) + " books that are similar to " + item(item_id) + "...")
    print("-------")
    recs = results[item_id][:num]
    for rec in recs:
        print("Recommended: " + item(rec[1]) + " (score:" + str(rec[0]) + ")")

# %%
print('How many new books would you like to learn about?')
num_books = input()

# %%
recommend(item_id=109, num=3)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ## References

# %% [markdown]
# To come
