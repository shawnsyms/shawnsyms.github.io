# %% [markdown]
# # #readMoreCanlit | Notebook 3: Data cleaning

# %% [markdown]
# ### Imports

# %%
# pandas and numpy
import pandas as pd
import numpy as np

# nltk imports
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer

# sci-kit learn imports
from sklearn.compose import make_column_transformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.pipeline import Pipeline, make_pipeline

# Presentation and visuals
import seaborn as sns
import matplotlib.pyplot as plt

# This magic line will allow you to generate plots
# within the Jupyter notebook.
# %matplotlib inline
from pprint import pprint
pd.options.display.max_seq_items = 2000
pd.options.display.max_rows = 4000
# pd.set_option(display.max_columns), None

# other imports
import json
import lxml
from lxml import html
import random
import regex as re
import requests
import time
import urllib.request
from datetime import datetime

# %% [markdown]
# # Data cleaning

# %%
# Read in the Canadian data

canadian = pd.read_csv('../data/processed/canadian_books.csv')
canadian = canadian.applymap(str)
canadian.shape
# Out:
# (8004, 5)

# %%
canadian
# Out:
#         id                                              title  \
# 0        0           01 Nathaniel Mcdaniel and Bigbeards Hook
# 1        1  02 Standard of Honor Book Two of the Templar T...
# 2        2                  03 Knights Templar Order in Chaos
# 3        3  100 Easy-to-Grow Native Plants for Canadian Ga...
# 4        4                                           10 Women
# ...    ...                                                ...
# 7999  7999                                           Zero Day
# 8000  8000                                         Zip's File
# 8001  8001                                           Zolitude
# 8002  8002                                    Zoo and Crowbar
# 8003  8003                                 Zora, A Cruel Tale
#
#                    author                                        description  \
# 0            Evan Solomon  Meet Nathaniel McDaniel, the mischievous hero ...
# 1              Jack Whyte  Jack Whyte’s thrilling Templar Trilogy continu...
# 2              Jack Whyte  In the final novel in the Templar Trilogy, Wil...
# 3        Lorraine Johnson  The key to a carefree garden is to know which ...
# 4         George Bowering  Ten Women is a new collection of short fiction...
# ...                   ...                                                ...
# 7999        Ezekiel Boone  The wildly entertaining, deeply satisfying fin...
# 8000      Shannon Maguire  Zip's File: A Romance of Silence explores the ...
# 8001         Paige Cooper  WINNER OF THE 2018 QUEBEC WRITERS' FEDERATION ...
# 8002        David Zieroth  The Wind has mysteriously caused the death of ...
# 8003  Philippe Arseneault  Arsenault’s Rabelaisian fantasy is a gothic ta...
#
#                                                   image
# 0     https://images.49thshelf.com/var/ezflow_site/s...
# 1     https://images.49thshelf.com/var/ezflow_site/s...
# 2     https://images.49thshelf.com/var/ezflow_site/s...
# 3     https://images.49thshelf.com/var/ezflow_site/s...
# 4     https://images.49thshelf.com/var/ezflow_site/s...
# ...                                                 ...
# 7999  https://images.49thshelf.com/var/ezflow_site/s...
# 8000  https://images.49thshelf.com/var/ezflow_site/s...
# 8001  https://images.49thshelf.com/var/ezflow_site/s...
# 8002  https://images.49thshelf.com/var/ezflow_site/s...
# 8003  https://images.49thshelf.com/var/ezflow_site/s...
#
# [8004 rows x 5 columns]

# %%
canadian.drop_duplicates(inplace = True)

# %%
canadian
# Out:
#         id                                              title  \
# 0        0           01 Nathaniel Mcdaniel and Bigbeards Hook
# 1        1  02 Standard of Honor Book Two of the Templar T...
# 2        2                  03 Knights Templar Order in Chaos
# 3        3  100 Easy-to-Grow Native Plants for Canadian Ga...
# 4        4                                           10 Women
# ...    ...                                                ...
# 7999  7999                                           Zero Day
# 8000  8000                                         Zip's File
# 8001  8001                                           Zolitude
# 8002  8002                                    Zoo and Crowbar
# 8003  8003                                 Zora, A Cruel Tale
#
#                    author                                        description  \
# 0            Evan Solomon  Meet Nathaniel McDaniel, the mischievous hero ...
# 1              Jack Whyte  Jack Whyte’s thrilling Templar Trilogy continu...
# 2              Jack Whyte  In the final novel in the Templar Trilogy, Wil...
# 3        Lorraine Johnson  The key to a carefree garden is to know which ...
# 4         George Bowering  Ten Women is a new collection of short fiction...
# ...                   ...                                                ...
# 7999        Ezekiel Boone  The wildly entertaining, deeply satisfying fin...
# 8000      Shannon Maguire  Zip's File: A Romance of Silence explores the ...
# 8001         Paige Cooper  WINNER OF THE 2018 QUEBEC WRITERS' FEDERATION ...
# 8002        David Zieroth  The Wind has mysteriously caused the death of ...
# 8003  Philippe Arseneault  Arsenault’s Rabelaisian fantasy is a gothic ta...
#
#                                                   image
# 0     https://images.49thshelf.com/var/ezflow_site/s...
# 1     https://images.49thshelf.com/var/ezflow_site/s...
# 2     https://images.49thshelf.com/var/ezflow_site/s...
# 3     https://images.49thshelf.com/var/ezflow_site/s...
# 4     https://images.49thshelf.com/var/ezflow_site/s...
# ...                                                 ...
# 7999  https://images.49thshelf.com/var/ezflow_site/s...
# 8000  https://images.49thshelf.com/var/ezflow_site/s...
# 8001  https://images.49thshelf.com/var/ezflow_site/s...
# 8002  https://images.49thshelf.com/var/ezflow_site/s...
# 8003  https://images.49thshelf.com/var/ezflow_site/s...
#
# [8004 rows x 5 columns]

# %%
canadian.dtypes
# Out:
# id             object
# title          object
# author         object
# description    object
# image          object
# dtype: object

# %%
canadian.to_csv('../data/processed/canadian_ready_for_model.csv')
