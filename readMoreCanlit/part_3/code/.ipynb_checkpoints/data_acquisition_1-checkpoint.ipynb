# %% [markdown]
# ### Imports

# %%
# pandas and numpy
import pandas as pd
import numpy as np

# nltk imports
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer

# sci-kit learn imports
from sklearn.compose import make_column_transformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.pipeline import Pipeline, make_pipeline

# Presentation and visuals
import seaborn as sns
import matplotlib.pyplot as plt

# This magic line will allow you to generate plots
# within the Jupyter notebook.
# %matplotlib inline
from pprint import pprint
pd.options.display.max_seq_items = 2000
pd.options.display.max_rows = 4000
# pd.set_option(display.max_columns), None

# other imports
import json
import lxml
from lxml import html
import random
import regex as re
import requests
import time
import urllib.request
from datetime import datetime

# %% [markdown]
# # Data acquisition

# %%
isbn = pd.read_csv('../data/data_acquisition/international2_for_download.csv')
isbn = isbn.applymap(str)
isbn.dtypes
# Out:
# isbn        object
# title       object
# authors     object
# overview    object
# dtype: object

# %%
isbn = isbn[:15000]
isbn
# Out:
#                 isbn title authors overview
# 0      9780152017743   nan     nan      nan
# 1      9780152017750   nan     nan      nan
# 2      9780152017866   nan     nan      nan
# 3      9780152017873   nan     nan      nan
# 4      9780152017903   nan     nan      nan
# ...              ...   ...     ...      ...
# 14995  9780226735429   nan     nan      nan
# 14996  9780226735573   nan     nan      nan
# 14997  9780226736280   nan     nan      nan
# 14998  9780226736334   nan     nan      nan
# 14999  9780226736341   nan     nan      nan
#
# [15000 rows x 4 columns]

# %%
for j in range(len(isbn)):

    header = {'Authorization': '44023_23ab132f3977ad9849e8f1a5d7dc73bf'}
    base_url = ('https://api2.isbndb.com/book/')
    response = requests.get(base_url + isbn['isbn'][j], headers=header)
    payload = response.json()
      
    try:
        isbn['title'][j] = payload['book']['title']
    
    except:
        isbn['title'][j] = np.nan
    
    try:
        isbn['authors'][j] = payload['book']['authors']
    
    except:
        isbn['authors'][j] = np.nan
              
    try:
        isbn['overview'][j] = payload['book']['overview']
    
    except:
        isbn['overview'][j] = np.nan
  
    print('Info downloaded for book ' + str(j + 1) + ' of ' +  str(len(isbn)) + ' books.')
              
    time.sleep(1)
# Out:
# Info downloaded for book 1 of 15000 books.
# Info downloaded for book 2 of 15000 books.
# Info downloaded for book 3 of 15000 books.
# Info downloaded for book 4 of 15000 books.
# Info downloaded for book 5 of 15000 books.
# Info downloaded for book 6 of 15000 books.
# Info downloaded for book 7 of 15000 books.
# Info downloaded for book 8 of 15000 books.
# Info downloaded for book 9 of 15000 books.
# Info downloaded for book 10 of 15000 books.
# Info downloaded for book 11 of 15000 books.
# Info downloaded for book 12 of 15000 books.
# Info downloaded for book 13 of 15000 books.
# Info downloaded for book 14 of 15000 books.
# Info downloaded for book 15 of 15000 books.
# Info downloaded for book 16 of 15000 books.
# Info downloaded for book 17 of 15000 books.
# Info downloaded for book 18 of 15000 books.
# Info downloaded for book 19 of 15000 books.
# Info downloaded for book 20 of 15000 books.
# Info downloaded for book 21 of 15000 books.
# Info downloaded for book 22 of 15000 books.
# Info downloaded for book 23 of 15000 books.
# Info downloaded for book 24 of 15000 books.
# Info downloaded for book 25 of 15000 books.
# Info downloaded for book 26 of 15000 books.
# Info downloaded for book 27 of 15000 books.
# Info downloaded for book 28 of 15000 books.
# Info downloaded for book 29 of 15000 books.
# Info downloaded for book 30 of 15000 books.
# Info downloaded for book 31 of 15000 books.
# Info downloaded for book 32 of 15000 books.
# Info downloaded for book 33 of 15000 books.
# Info downloaded for book 34 of 15000 books.
# Info downloaded for book 35 of 15000 books.
# Info downloaded for book 36 of 15000 books.
# Info downloaded for book 37 of 15000 books.
# Info downloaded for book 38 of 15000 books.
# Info downloaded for book 39 of 15000 books.
# Info downloaded for book 40 of 15000 books.
# Info downloaded for book 41 of 15000 books.
# Info downloaded for book 42 of 15000 books.
# Info downloaded for book 43 of 15000 books.
# Info downloaded for book 44 of 15000 books.
# Info downloaded for book 45 of 15000 books.
# Info downloaded for book 46 of 15000 books.
# Info downloaded for book 47 of 15000 books.
# Info downloaded for book 48 of 15000 books.
# Info downloaded for book 49 of 15000 books.
# Info downloaded for book 50 of 15000 books.
# Info downloaded for book 51 of 15000 books.
# Info downloaded for book 52 of 15000 books.
# Info downloaded for book 53 of 15000 books.
# Info downloaded for book 54 of 15000 books.
# Info downloaded for book 55 of 15000 books.
# Info downloaded for book 56 of 15000 books.
# Info downloaded for book 57 of 15000 books.
# Info downloaded for book 58 of 15000 books.
# Info downloaded for book 59 of 15000 books.
# Info downloaded for book 60 of 15000 books.
# Info downloaded for book 61 of 15000 books.
# Info downloaded for book 62 of 15000 books.
# Info downloaded for book 63 of 15000 books.
# Info downloaded for book 64 of 15000 books.
# Info downloaded for book 65 of 15000 books.
# Info downloaded for book 66 of 15000 books.
# Info downloaded for book 67 of 15000 books.
# Info downloaded for book 68 of 15000 books.
# Info downloaded for book 69 of 15000 books.
# Info downloaded for book 70 of 15000 books.
# Info downloaded for book 71 of 15000 books.
# Info downloaded for book 72 of 15000 books.
# Info downloaded for book 73 of 15000 books.
# Info downloaded for book 74 of 15000 books.
# Info downloaded for book 75 of 15000 books.
# Info downloaded for book 76 of 15000 books.
# Info downloaded for book 77 of 15000 books.
# Info downloaded for book 78 of 15000 books.
# Info downloaded for book 79 of 15000 books.
# Info downloaded for book 80 of 15000 books.
# Info downloaded for book 81 of 15000 books.
# Info downloaded for book 82 of 15000 books.
# Info downloaded for book 83 of 15000 books.
# Info downloaded for book 84 of 15000 books.
# Info downloaded for book 85 of 15000 books.
# Info downloaded for book 86 of 15000 books.
# Info downloaded for book 87 of 15000 books.
# Info downloaded for book 88 of 15000 books.
# Info downloaded for book 89 of 15000 books.
# Info downloaded for book 90 of 15000 books.
# Info downloaded for book 91 of 15000 books.
# Info downloaded for book 92 of 15000 books.
# Info downloaded for book 93 of 15000 books.
# Info downloaded for book 94 of 15000 books.
# Info downloaded for book 95 of 15000 books.
# Info downloaded for book 96 of 15000 books.
# Info downloaded for book 97 of 15000 books.
# Info downloaded for book 98 of 15000 books.
# Info downloaded for book 99 of 15000 books.
# Info downloaded for book 100 of 15000 books.
# Info downloaded for book 101 of 15000 books.
# Info downloaded for book 102 of 15000 books.
# Info downloaded for book 103 of 15000 books.
# Info downloaded for book 104 of 15000 books.
# Info downloaded for book 105 of 15000 books.
# Info downloaded for book 106 of 15000 books.
# Info downloaded for book 107 of 15000 books.
# Info downloaded for book 108 of 15000 books.
# Info downloaded for book 109 of 15000 books.
# Info downloaded for book 110 of 15000 books.
# Info downloaded for book 111 of 15000 books.
# Info downloaded for book 112 of 15000 books.
# Info downloaded for book 113 of 15000 books.
# Info downloaded for book 114 of 15000 books.
# Info downloaded for book 115 of 15000 books.
# Info downloaded for book 116 of 15000 books.
# Info downloaded for book 117 of 15000 books.
# Info downloaded for book 118 of 15000 books.
# Info downloaded for book 119 of 15000 books.
# Info downloaded for book 120 of 15000 books.
# Info downloaded for book 121 of 15000 books.
# Info downloaded for book 122 of 15000 books.
# Info downloaded for book 123 of 15000 books.
# Info downloaded for book 124 of 15000 books.
# Info downloaded for book 125 of 15000 books.
# Info downloaded for book 126 of 15000 books.
# Info downloaded for book 127 of 15000 books.
# Info downloaded for book 128 of 15000 books.
# Info downloaded for book 129 of 15000 books.
# Info downloaded for book 130 of 15000 books.
# Info downloaded for book 131 of 15000 books.
# Info downloaded for book 132 of 15000 books.
# Info downloaded for book 133 of 15000 books.
# Info downloaded for book 134 of 15000 books.
# Info downloaded for book 135 of 15000 books.
# Info downloaded for book 136 of 15000 books.
# Info downloaded for book 137 of 15000 books.
# Info downloaded for book 138 of 15000 books.
# Info downloaded for book 139 of 15000 books.
# Info downloaded for book 140 of 15000 books.
# Info downloaded for book 141 of 15000 books.
# Info downloaded for book 142 of 15000 books.
# Info downloaded for book 143 of 15000 books.
# Info downloaded for book 144 of 15000 books.
# Info downloaded for book 145 of 15000 books.
# Info downloaded for book 146 of 15000 books.
# Info downloaded for book 147 of 15000 books.
# Info downloaded for book 148 of 15000 books.
# Info downloaded for book 149 of 15000 books.
# Info downloaded for book 150 of 15000 books.
# Info downloaded for book 151 of 15000 books.
# Info downloaded for book 152 of 15000 books.
# Info downloaded for book 153 of 15000 books.
# Info downloaded for book 154 of 15000 books.
# Info downloaded for book 155 of 15000 books.
# Info downloaded for book 156 of 15000 books.
# Info downloaded for book 157 of 15000 books.
# Info downloaded for book 158 of 15000 books.
# Info downloaded for book 159 of 15000 books.
# Info downloaded for book 160 of 15000 books.
# Info downloaded for book 161 of 15000 books.
# Info downloaded for book 162 of 15000 books.
# Info downloaded for book 163 of 15000 books.
# Info downloaded for book 164 of 15000 books.
# Info downloaded for book 165 of 15000 books.
# Info downloaded for book 166 of 15000 books.
# Info downloaded for book 167 of 15000 books.
# Info downloaded for book 168 of 15000 books.
# Info downloaded for book 169 of 15000 books.
# Info downloaded for book 170 of 15000 books.
# Info downloaded for book 171 of 15000 books.
# Info downloaded for book 172 of 15000 books.
# Info downloaded for book 173 of 15000 books.
# Info downloaded for book 174 of 15000 books.
# Info downloaded for book 175 of 15000 books.
# Info downloaded for book 176 of 15000 books.
# Info downloaded for book 177 of 15000 books.
# Info downloaded for book 178 of 15000 books.
# Info downloaded for book 179 of 15000 books.
# Info downloaded for book 180 of 15000 books.
# Info downloaded for book 181 of 15000 books.
# Info downloaded for book 182 of 15000 books.
# Info downloaded for book 183 of 15000 books.
# Info downloaded for book 184 of 15000 books.
# Info downloaded for book 185 of 15000 books.
# Info downloaded for book 186 of 15000 books.
# Info downloaded for book 187 of 15000 books.
# Info downloaded for book 188 of 15000 books.
# Info downloaded for book 189 of 15000 books.
# Info downloaded for book 190 of 15000 books.
# Info downloaded for book 191 of 15000 books.
# Info downloaded for book 192 of 15000 books.
# Info downloaded for book 193 of 15000 books.
# Info downloaded for book 194 of 15000 books.
# Info downloaded for book 195 of 15000 books.
# Info downloaded for book 196 of 15000 books.
# Info downloaded for book 197 of 15000 books.
# Info downloaded for book 198 of 15000 books.
# Info downloaded for book 199 of 15000 books.
# Info downloaded for book 200 of 15000 books.
# Info downloaded for book 201 of 15000 books.
# Info downloaded for book 202 of 15000 books.
# Info downloaded for book 203 of 15000 books.
# Info downloaded for book 204 of 15000 books.
# Info downloaded for book 205 of 15000 books.
# Info downloaded for book 206 of 15000 books.
# Info downloaded for book 207 of 15000 books.
# Info downloaded for book 208 of 15000 books.
# Info downloaded for book 209 of 15000 books.
# Info downloaded for book 210 of 15000 books.
# Info downloaded for book 211 of 15000 books.
# Info downloaded for book 212 of 15000 books.
# Info downloaded for book 213 of 15000 books.
# Info downloaded for book 214 of 15000 books.
# Info downloaded for book 215 of 15000 books.
# Info downloaded for book 216 of 15000 books.
# Info downloaded for book 217 of 15000 books.
# Info downloaded for book 218 of 15000 books.
# Info downloaded for book 219 of 15000 books.
# Info downloaded for book 220 of 15000 books.
# Info downloaded for book 221 of 15000 books.
# Info downloaded for book 222 of 15000 books.
# Info downloaded for book 223 of 15000 books.
# Info downloaded for book 224 of 15000 books.
# Info downloaded for book 225 of 15000 books.
# Info downloaded for book 226 of 15000 books.
# Info downloaded for book 227 of 15000 books.
# Info downloaded for book 228 of 15000 books.
# Info downloaded for book 229 of 15000 books.
# Info downloaded for book 230 of 15000 books.
# Info downloaded for book 231 of 15000 books.
# Info downloaded for book 232 of 15000 books.
# Info downloaded for book 233 of 15000 books.
# Info downloaded for book 234 of 15000 books.
# Info downloaded for book 235 of 15000 books.
# Info downloaded for book 236 of 15000 books.
# Info downloaded for book 237 of 15000 books.
# Info downloaded for book 238 of 15000 books.
# Info downloaded for book 239 of 15000 books.
# Info downloaded for book 240 of 15000 books.
# Info downloaded for book 241 of 15000 books.
# Info downloaded for book 242 of 15000 books.
# Info downloaded for book 243 of 15000 books.
# Info downloaded for book 244 of 15000 books.
# Info downloaded for book 245 of 15000 books.
# Info downloaded for book 246 of 15000 books.
# Info downloaded for book 247 of 15000 books.
# Info downloaded for book 248 of 15000 books.
# Info downloaded for book 249 of 15000 books.
# Info downloaded for book 250 of 15000 books.
# Info downloaded for book 251 of 15000 books.
# Info downloaded for book 252 of 15000 books.
# Info downloaded for book 253 of 15000 books.
# Info downloaded for book 254 of 15000 books.
# Info downloaded for book 255 of 15000 books.
# Info downloaded for book 256 of 15000 books.
# Info downloaded for book 257 of 15000 books.
# Info downloaded for book 258 of 15000 books.
# Info downloaded for book 259 of 15000 books.
# Info downloaded for book 260 of 15000 books.
# Info downloaded for book 261 of 15000 books.
# Info downloaded for book 262 of 15000 books.
# Info downloaded for book 263 of 15000 books.
# Info downloaded for book 264 of 15000 books.
# Info downloaded for book 265 of 15000 books.
# Info downloaded for book 266 of 15000 books.
# Info downloaded for book 267 of 15000 books.
# Info downloaded for book 268 of 15000 books.
# Info downloaded for book 269 of 15000 books.
# Info downloaded for book 270 of 15000 books.
# Info downloaded for book 271 of 15000 books.
# Info downloaded for book 272 of 15000 books.
# Info downloaded for book 273 of 15000 books.
# Info downloaded for book 274 of 15000 books.
# Info downloaded for book 275 of 15000 books.
# Info downloaded for book 276 of 15000 books.
# Info downloaded for book 277 of 15000 books.
# Info downloaded for book 278 of 15000 books.
# Info downloaded for book 279 of 15000 books.
# Info downloaded for book 280 of 15000 books.
# Info downloaded for book 281 of 15000 books.
# Info downloaded for book 282 of 15000 books.
# Info downloaded for book 283 of 15000 books.
# Info downloaded for book 284 of 15000 books.
# Info downloaded for book 285 of 15000 books.
# Info downloaded for book 286 of 15000 books.
# Info downloaded for book 287 of 15000 books.
# Info downloaded for book 288 of 15000 books.
# Info downloaded for book 289 of 15000 books.
# Info downloaded for book 290 of 15000 books.
# Info downloaded for book 291 of 15000 books.
# Info downloaded for book 292 of 15000 books.
# Info downloaded for book 293 of 15000 books.
# Info downloaded for book 294 of 15000 books.
# Info downloaded for book 295 of 15000 books.
# Info downloaded for book 296 of 15000 books.
# Info downloaded for book 297 of 15000 books.
# Info downloaded for book 298 of 15000 books.
# Info downloaded for book 299 of 15000 books.
# Info downloaded for book 300 of 15000 books.
# Info downloaded for book 301 of 15000 books.
# Info downloaded for book 302 of 15000 books.
# Info downloaded for book 303 of 15000 books.
# Info downloaded for book 304 of 15000 books.
# Info downloaded for book 305 of 15000 books.
# Info downloaded for book 306 of 15000 books.
# Info downloaded for book 307 of 15000 books.
# Info downloaded for book 308 of 15000 books.
# Info downloaded for book 309 of 15000 books.
# Info downloaded for book 310 of 15000 books.
# Info downloaded for book 311 of 15000 books.
# Info downloaded for book 312 of 15000 books.
# Info downloaded for book 313 of 15000 books.
# Info downloaded for book 314 of 15000 books.
# Info downloaded for book 315 of 15000 books.
# Info downloaded for book 316 of 15000 books.
# Info downloaded for book 317 of 15000 books.
# Info downloaded for book 318 of 15000 books.
# Info downloaded for book 319 of 15000 books.
# Info downloaded for book 320 of 15000 books.
# Info downloaded for book 321 of 15000 books.
# Info downloaded for book 322 of 15000 books.
# Info downloaded for book 323 of 15000 books.
# Info downloaded for book 324 of 15000 books.
# Info downloaded for book 325 of 15000 books.
# Info downloaded for book 326 of 15000 books.
# Info downloaded for book 327 of 15000 books.
# Info downloaded for book 328 of 15000 books.
# Info downloaded for book 329 of 15000 books.
# Info downloaded for book 330 of 15000 books.
# Info downloaded for book 331 of 15000 books.
# Info downloaded for book 332 of 15000 books.
# Info downloaded for book 333 of 15000 books.
# Info downloaded for book 334 of 15000 books.
# Info downloaded for book 335 of 15000 books.
# Info downloaded for book 336 of 15000 books.
# Info downloaded for book 337 of 15000 books.
# Info downloaded for book 338 of 15000 books.
# Info downloaded for book 339 of 15000 books.
# Info downloaded for book 340 of 15000 books.
# Info downloaded for book 341 of 15000 books.
# Info downloaded for book 342 of 15000 books.
# Info downloaded for book 343 of 15000 books.
# Info downloaded for book 344 of 15000 books.
# Info downloaded for book 345 of 15000 books.
# Info downloaded for book 346 of 15000 books.
# Info downloaded for book 347 of 15000 books.
# Info downloaded for book 348 of 15000 books.
# Info downloaded for book 349 of 15000 books.
# Info downloaded for book 350 of 15000 books.
# Info downloaded for book 351 of 15000 books.
# Info downloaded for book 352 of 15000 books.
# Info downloaded for book 353 of 15000 books.
# Info downloaded for book 354 of 15000 books.
# Info downloaded for book 355 of 15000 books.
# Info downloaded for book 356 of 15000 books.
# Info downloaded for book 357 of 15000 books.
# Info downloaded for book 358 of 15000 books.
# Info downloaded for book 359 of 15000 books.
# Info downloaded for book 360 of 15000 books.
# Info downloaded for book 361 of 15000 books.
# Info downloaded for book 362 of 15000 books.
# Info downloaded for book 363 of 15000 books.
# Info downloaded for book 364 of 15000 books.
# Info downloaded for book 365 of 15000 books.
# Info downloaded for book 366 of 15000 books.
# Info downloaded for book 367 of 15000 books.
# Info downloaded for book 368 of 15000 books.
# Info downloaded for book 369 of 15000 books.
# Info downloaded for book 370 of 15000 books.
# Info downloaded for book 371 of 15000 books.
# Info downloaded for book 372 of 15000 books.
# Info downloaded for book 373 of 15000 books.
# Info downloaded for book 374 of 15000 books.
# Info downloaded for book 375 of 15000 books.
# Info downloaded for book 376 of 15000 books.
# Info downloaded for book 377 of 15000 books.
# Info downloaded for book 378 of 15000 books.
# Info downloaded for book 379 of 15000 books.
# Info downloaded for book 380 of 15000 books.
# Info downloaded for book 381 of 15000 books.
# Info downloaded for book 382 of 15000 books.
# Info downloaded for book 383 of 15000 books.
# Info downloaded for book 384 of 15000 books.
# Info downloaded for book 385 of 15000 books.
# Info downloaded for book 386 of 15000 books.
# Info downloaded for book 387 of 15000 books.
# Info downloaded for book 388 of 15000 books.
# Info downloaded for book 389 of 15000 books.
# Info downloaded for book 390 of 15000 books.
# Info downloaded for book 391 of 15000 books.
# Info downloaded for book 392 of 15000 books.
# Info downloaded for book 393 of 15000 books.
# Info downloaded for book 394 of 15000 books.
# Info downloaded for book 395 of 15000 books.
# Info downloaded for book 396 of 15000 books.
# Info downloaded for book 397 of 15000 books.
# Info downloaded for book 398 of 15000 books.
# Info downloaded for book 399 of 15000 books.
# Info downloaded for book 400 of 15000 books.
# Info downloaded for book 401 of 15000 books.
# Info downloaded for book 402 of 15000 books.
# Info downloaded for book 403 of 15000 books.
# Info downloaded for book 404 of 15000 books.
# Info downloaded for book 405 of 15000 books.
# Info downloaded for book 406 of 15000 books.
# Info downloaded for book 407 of 15000 books.
# Info downloaded for book 408 of 15000 books.
# Info downloaded for book 409 of 15000 books.
# Info downloaded for book 410 of 15000 books.
# Info downloaded for book 411 of 15000 books.
# Info downloaded for book 412 of 15000 books.
# Info downloaded for book 413 of 15000 books.
# Info downloaded for book 414 of 15000 books.
# Info downloaded for book 415 of 15000 books.
# Info downloaded for book 416 of 15000 books.
# Info downloaded for book 417 of 15000 books.
# Info downloaded for book 418 of 15000 books.
# Info downloaded for book 419 of 15000 books.
# Info downloaded for book 420 of 15000 books.
# Info downloaded for book 421 of 15000 books.
# Info downloaded for book 422 of 15000 books.
# Info downloaded for book 423 of 15000 books.
# Info downloaded for book 424 of 15000 books.
# Info downloaded for book 425 of 15000 books.
# Info downloaded for book 426 of 15000 books.
# Info downloaded for book 427 of 15000 books.
# Info downloaded for book 428 of 15000 books.
# Info downloaded for book 429 of 15000 books.
# Info downloaded for book 430 of 15000 books.
# Info downloaded for book 431 of 15000 books.
# Info downloaded for book 432 of 15000 books.
# Info downloaded for book 433 of 15000 books.
# Info downloaded for book 434 of 15000 books.
# Info downloaded for book 435 of 15000 books.
# Info downloaded for book 436 of 15000 books.
# Info downloaded for book 437 of 15000 books.
# Info downloaded for book 438 of 15000 books.
# Info downloaded for book 439 of 15000 books.
# Info downloaded for book 440 of 15000 books.
# Info downloaded for book 441 of 15000 books.
# Info downloaded for book 442 of 15000 books.
# Info downloaded for book 443 of 15000 books.
# Info downloaded for book 444 of 15000 books.
# Info downloaded for book 445 of 15000 books.
# Info downloaded for book 446 of 15000 books.
# Info downloaded for book 447 of 15000 books.
# Info downloaded for book 448 of 15000 books.
# Info downloaded for book 449 of 15000 books.
# Info downloaded for book 450 of 15000 books.
# Info downloaded for book 451 of 15000 books.
# Info downloaded for book 452 of 15000 books.
# Info downloaded for book 453 of 15000 books.
# Info downloaded for book 454 of 15000 books.
# Info downloaded for book 455 of 15000 books.
# Info downloaded for book 456 of 15000 books.
# Info downloaded for book 457 of 15000 books.
# Info downloaded for book 458 of 15000 books.
# Info downloaded for book 459 of 15000 books.
# Info downloaded for book 460 of 15000 books.
# Info downloaded for book 461 of 15000 books.
# Info downloaded for book 462 of 15000 books.
# Info downloaded for book 463 of 15000 books.
# Info downloaded for book 464 of 15000 books.
# Info downloaded for book 465 of 15000 books.
# Info downloaded for book 466 of 15000 books.
# Info downloaded for book 467 of 15000 books.
# Info downloaded for book 468 of 15000 books.
# Info downloaded for book 469 of 15000 books.
# Info downloaded for book 470 of 15000 books.
# Info downloaded for book 471 of 15000 books.
# Info downloaded for book 472 of 15000 books.
# Info downloaded for book 473 of 15000 books.
# Info downloaded for book 474 of 15000 books.
# Info downloaded for book 475 of 15000 books.
# Info downloaded for book 476 of 15000 books.
# Info downloaded for book 477 of 15000 books.
# Info downloaded for book 478 of 15000 books.
# Info downloaded for book 479 of 15000 books.
# Info downloaded for book 480 of 15000 books.
# Info downloaded for book 481 of 15000 books.
# Info downloaded for book 482 of 15000 books.
# Info downloaded for book 483 of 15000 books.
# Info downloaded for book 484 of 15000 books.
# Info downloaded for book 485 of 15000 books.
# Info downloaded for book 486 of 15000 books.
# Info downloaded for book 487 of 15000 books.
# Info downloaded for book 488 of 15000 books.
# Info downloaded for book 489 of 15000 books.
# Info downloaded for book 490 of 15000 books.
# Info downloaded for book 491 of 15000 books.
# Info downloaded for book 492 of 15000 books.
# Info downloaded for book 493 of 15000 books.
# Info downloaded for book 494 of 15000 books.
# Info downloaded for book 495 of 15000 books.
# Info downloaded for book 496 of 15000 books.
# Info downloaded for book 497 of 15000 books.
# Info downloaded for book 498 of 15000 books.
# Info downloaded for book 499 of 15000 books.
# Info downloaded for book 500 of 15000 books.
# Info downloaded for book 501 of 15000 books.
# Info downloaded for book 502 of 15000 books.
# Info downloaded for book 503 of 15000 books.
# Info downloaded for book 504 of 15000 books.
# Info downloaded for book 505 of 15000 books.
# Info downloaded for book 506 of 15000 books.
# Info downloaded for book 507 of 15000 books.
# Info downloaded for book 508 of 15000 books.
# Info downloaded for book 509 of 15000 books.
# Info downloaded for book 510 of 15000 books.
# Info downloaded for book 511 of 15000 books.
# Info downloaded for book 512 of 15000 books.
# Info downloaded for book 513 of 15000 books.
# Info downloaded for book 514 of 15000 books.
# Info downloaded for book 515 of 15000 books.
# Info downloaded for book 516 of 15000 books.
# Info downloaded for book 517 of 15000 books.
# Info downloaded for book 518 of 15000 books.
# Info downloaded for book 519 of 15000 books.
# Info downloaded for book 520 of 15000 books.
# Info downloaded for book 521 of 15000 books.
# Info downloaded for book 522 of 15000 books.
# Info downloaded for book 523 of 15000 books.
# Info downloaded for book 524 of 15000 books.
# Info downloaded for book 525 of 15000 books.
# Info downloaded for book 526 of 15000 books.
# Info downloaded for book 527 of 15000 books.
# Info downloaded for book 528 of 15000 books.
# Info downloaded for book 529 of 15000 books.
# Info downloaded for book 530 of 15000 books.
# Info downloaded for book 531 of 15000 books.
# Info downloaded for book 532 of 15000 books.
# Info downloaded for book 533 of 15000 books.
# Info downloaded for book 534 of 15000 books.
# Info downloaded for book 535 of 15000 books.
# Info downloaded for book 536 of 15000 books.
# Info downloaded for book 537 of 15000 books.
# Info downloaded for book 538 of 15000 books.
# Info downloaded for book 539 of 15000 books.
# Info downloaded for book 540 of 15000 books.
# Info downloaded for book 541 of 15000 books.
# Info downloaded for book 542 of 15000 books.
# Info downloaded for book 543 of 15000 books.
# Info downloaded for book 544 of 15000 books.
# Info downloaded for book 545 of 15000 books.
# Info downloaded for book 546 of 15000 books.
# Info downloaded for book 547 of 15000 books.
# Info downloaded for book 548 of 15000 books.
# Info downloaded for book 549 of 15000 books.
# Info downloaded for book 550 of 15000 books.
# Info downloaded for book 551 of 15000 books.
# Info downloaded for book 552 of 15000 books.
# Info downloaded for book 553 of 15000 books.
# Info downloaded for book 554 of 15000 books.
# Info downloaded for book 555 of 15000 books.
# Info downloaded for book 556 of 15000 books.
# Info downloaded for book 557 of 15000 books.
# Info downloaded for book 558 of 15000 books.
# Info downloaded for book 559 of 15000 books.
# Info downloaded for book 560 of 15000 books.
# Info downloaded for book 561 of 15000 books.
# Info downloaded for book 562 of 15000 books.
# Info downloaded for book 563 of 15000 books.
# Info downloaded for book 564 of 15000 books.
# Info downloaded for book 565 of 15000 books.
# Info downloaded for book 566 of 15000 books.
# Info downloaded for book 567 of 15000 books.
# Info downloaded for book 568 of 15000 books.
# Info downloaded for book 569 of 15000 books.
# Info downloaded for book 570 of 15000 books.
# Info downloaded for book 571 of 15000 books.
# Info downloaded for book 572 of 15000 books.
# Info downloaded for book 573 of 15000 books.
# Info downloaded for book 574 of 15000 books.
# Info downloaded for book 575 of 15000 books.
# Info downloaded for book 576 of 15000 books.
# Info downloaded for book 577 of 15000 books.
# Info downloaded for book 578 of 15000 books.
# Info downloaded for book 579 of 15000 books.
# Info downloaded for book 580 of 15000 books.
# Info downloaded for book 581 of 15000 books.
# Info downloaded for book 582 of 15000 books.
# Info downloaded for book 583 of 15000 books.
# Info downloaded for book 584 of 15000 books.
# Info downloaded for book 585 of 15000 books.
# Info downloaded for book 586 of 15000 books.
# Info downloaded for book 587 of 15000 books.
# Info downloaded for book 588 of 15000 books.
# Info downloaded for book 589 of 15000 books.
# Info downloaded for book 590 of 15000 books.
# Info downloaded for book 591 of 15000 books.
# Info downloaded for book 592 of 15000 books.
# Info downloaded for book 593 of 15000 books.
# Info downloaded for book 594 of 15000 books.
# Info downloaded for book 595 of 15000 books.
# Info downloaded for book 596 of 15000 books.
# Info downloaded for book 597 of 15000 books.
# Info downloaded for book 598 of 15000 books.
# Info downloaded for book 599 of 15000 books.
# Info downloaded for book 600 of 15000 books.
# Info downloaded for book 601 of 15000 books.
# Info downloaded for book 602 of 15000 books.
# Info downloaded for book 603 of 15000 books.
# Info downloaded for book 604 of 15000 books.
# Info downloaded for book 605 of 15000 books.
# Info downloaded for book 606 of 15000 books.
# Info downloaded for book 607 of 15000 books.
# Info downloaded for book 608 of 15000 books.
# Info downloaded for book 609 of 15000 books.
# Info downloaded for book 610 of 15000 books.
# Info downloaded for book 611 of 15000 books.
# Info downloaded for book 612 of 15000 books.
# Info downloaded for book 613 of 15000 books.
# Info downloaded for book 614 of 15000 books.
# Info downloaded for book 615 of 15000 books.
# Info downloaded for book 616 of 15000 books.
# Info downloaded for book 617 of 15000 books.
# Info downloaded for book 618 of 15000 books.
# Info downloaded for book 619 of 15000 books.
# Info downloaded for book 620 of 15000 books.
# Info downloaded for book 621 of 15000 books.
# Info downloaded for book 622 of 15000 books.
# Info downloaded for book 623 of 15000 books.
# Info downloaded for book 624 of 15000 books.
# Info downloaded for book 625 of 15000 books.
# Info downloaded for book 626 of 15000 books.
# Info downloaded for book 627 of 15000 books.
# Info downloaded for book 628 of 15000 books.
# Info downloaded for book 629 of 15000 books.
# Info downloaded for book 630 of 15000 books.
# Info downloaded for book 631 of 15000 books.
# Info downloaded for book 632 of 15000 books.
# Info downloaded for book 633 of 15000 books.
# Info downloaded for book 634 of 15000 books.
# Info downloaded for book 635 of 15000 books.
# Info downloaded for book 636 of 15000 books.
# Info downloaded for book 637 of 15000 books.
# Info downloaded for book 638 of 15000 books.
# Info downloaded for book 639 of 15000 books.
# Info downloaded for book 640 of 15000 books.
# Info downloaded for book 641 of 15000 books.
# Info downloaded for book 642 of 15000 books.
# Info downloaded for book 643 of 15000 books.
# Info downloaded for book 644 of 15000 books.
# Info downloaded for book 645 of 15000 books.
# Info downloaded for book 646 of 15000 books.
# Info downloaded for book 647 of 15000 books.
# Info downloaded for book 648 of 15000 books.
# Info downloaded for book 649 of 15000 books.
# Info downloaded for book 650 of 15000 books.
# Info downloaded for book 651 of 15000 books.
# Info downloaded for book 652 of 15000 books.
# Info downloaded for book 653 of 15000 books.
# Info downloaded for book 654 of 15000 books.
# Info downloaded for book 655 of 15000 books.
# Info downloaded for book 656 of 15000 books.
# Info downloaded for book 657 of 15000 books.
# Info downloaded for book 658 of 15000 books.
# Info downloaded for book 659 of 15000 books.
# Info downloaded for book 660 of 15000 books.
# Info downloaded for book 661 of 15000 books.
# Info downloaded for book 662 of 15000 books.
# Info downloaded for book 663 of 15000 books.
# Info downloaded for book 664 of 15000 books.
# Info downloaded for book 665 of 15000 books.
# Info downloaded for book 666 of 15000 books.
# Info downloaded for book 667 of 15000 books.
# Info downloaded for book 668 of 15000 books.
# Info downloaded for book 669 of 15000 books.
# Info downloaded for book 670 of 15000 books.
# Info downloaded for book 671 of 15000 books.
# Info downloaded for book 672 of 15000 books.
# Info downloaded for book 673 of 15000 books.
# Info downloaded for book 674 of 15000 books.
# Info downloaded for book 675 of 15000 books.
# Info downloaded for book 676 of 15000 books.
# Info downloaded for book 677 of 15000 books.
# Info downloaded for book 678 of 15000 books.
# Info downloaded for book 679 of 15000 books.
# Info downloaded for book 680 of 15000 books.
# Info downloaded for book 681 of 15000 books.
# Info downloaded for book 682 of 15000 books.
# Info downloaded for book 683 of 15000 books.
# Info downloaded for book 684 of 15000 books.
# Info downloaded for book 685 of 15000 books.
# Info downloaded for book 686 of 15000 books.
# Info downloaded for book 687 of 15000 books.
# Info downloaded for book 688 of 15000 books.
# Info downloaded for book 689 of 15000 books.
# Info downloaded for book 690 of 15000 books.
# Info downloaded for book 691 of 15000 books.
# Info downloaded for book 692 of 15000 books.
# Info downloaded for book 693 of 15000 books.
# Info downloaded for book 694 of 15000 books.
# Info downloaded for book 695 of 15000 books.
# Info downloaded for book 696 of 15000 books.
# Info downloaded for book 697 of 15000 books.
# Info downloaded for book 698 of 15000 books.
# Info downloaded for book 699 of 15000 books.
# Info downloaded for book 700 of 15000 books.
# Info downloaded for book 701 of 15000 books.
# Info downloaded for book 702 of 15000 books.
# Info downloaded for book 703 of 15000 books.
# Info downloaded for book 704 of 15000 books.
# Info downloaded for book 705 of 15000 books.
# Info downloaded for book 706 of 15000 books.
# Info downloaded for book 707 of 15000 books.
# Info downloaded for book 708 of 15000 books.
# Info downloaded for book 709 of 15000 books.
# Info downloaded for book 710 of 15000 books.
# Info downloaded for book 711 of 15000 books.
# Info downloaded for book 712 of 15000 books.
# Info downloaded for book 713 of 15000 books.
# Info downloaded for book 714 of 15000 books.
# Info downloaded for book 715 of 15000 books.
# Info downloaded for book 716 of 15000 books.
# Info downloaded for book 717 of 15000 books.
# Info downloaded for book 718 of 15000 books.
# Info downloaded for book 719 of 15000 books.
# Info downloaded for book 720 of 15000 books.
# Info downloaded for book 721 of 15000 books.
# Info downloaded for book 722 of 15000 books.
# Info downloaded for book 723 of 15000 books.
# Info downloaded for book 724 of 15000 books.
# Info downloaded for book 725 of 15000 books.
# Info downloaded for book 726 of 15000 books.
# Info downloaded for book 727 of 15000 books.
# Info downloaded for book 728 of 15000 books.
# Info downloaded for book 729 of 15000 books.
# Info downloaded for book 730 of 15000 books.
# Info downloaded for book 731 of 15000 books.
# Info downloaded for book 732 of 15000 books.
# Info downloaded for book 733 of 15000 books.
# Info downloaded for book 734 of 15000 books.
# Info downloaded for book 735 of 15000 books.
# Info downloaded for book 736 of 15000 books.
# Info downloaded for book 737 of 15000 books.
# Info downloaded for book 738 of 15000 books.
# Info downloaded for book 739 of 15000 books.
# Info downloaded for book 740 of 15000 books.
# Info downloaded for book 741 of 15000 books.
# Info downloaded for book 742 of 15000 books.
# Info downloaded for book 743 of 15000 books.
# Info downloaded for book 744 of 15000 books.
# Info downloaded for book 745 of 15000 books.
# Info downloaded for book 746 of 15000 books.
# Info downloaded for book 747 of 15000 books.
# Info downloaded for book 748 of 15000 books.
# Info downloaded for book 749 of 15000 books.
# Info downloaded for book 750 of 15000 books.
# Info downloaded for book 751 of 15000 books.
# Info downloaded for book 752 of 15000 books.
# Info downloaded for book 753 of 15000 books.
# Info downloaded for book 754 of 15000 books.
# Info downloaded for book 755 of 15000 books.
# Info downloaded for book 756 of 15000 books.
# Info downloaded for book 757 of 15000 books.
# Info downloaded for book 758 of 15000 books.
# Info downloaded for book 759 of 15000 books.
# Info downloaded for book 760 of 15000 books.
# Info downloaded for book 761 of 15000 books.
# Info downloaded for book 762 of 15000 books.
# Info downloaded for book 763 of 15000 books.
# Info downloaded for book 764 of 15000 books.
# Info downloaded for book 765 of 15000 books.
# Info downloaded for book 766 of 15000 books.
# Info downloaded for book 767 of 15000 books.
# Info downloaded for book 768 of 15000 books.
# Info downloaded for book 769 of 15000 books.
# Info downloaded for book 770 of 15000 books.
# Info downloaded for book 771 of 15000 books.
# Info downloaded for book 772 of 15000 books.
# Info downloaded for book 773 of 15000 books.
# Info downloaded for book 774 of 15000 books.
# Info downloaded for book 775 of 15000 books.
# Info downloaded for book 776 of 15000 books.
# Info downloaded for book 777 of 15000 books.
# Info downloaded for book 778 of 15000 books.
# Info downloaded for book 779 of 15000 books.
# Info downloaded for book 780 of 15000 books.
# Info downloaded for book 781 of 15000 books.
# Info downloaded for book 782 of 15000 books.
# Info downloaded for book 783 of 15000 books.
# Info downloaded for book 784 of 15000 books.
# Info downloaded for book 785 of 15000 books.
# Info downloaded for book 786 of 15000 books.
# Info downloaded for book 787 of 15000 books.
# Info downloaded for book 788 of 15000 books.
# Info downloaded for book 789 of 15000 books.
# Info downloaded for book 790 of 15000 books.
# Info downloaded for book 791 of 15000 books.
# Info downloaded for book 792 of 15000 books.
# Info downloaded for book 793 of 15000 books.
# Info downloaded for book 794 of 15000 books.
# Info downloaded for book 795 of 15000 books.
# Info downloaded for book 796 of 15000 books.
# Info downloaded for book 797 of 15000 books.
# Info downloaded for book 798 of 15000 books.
# Info downloaded for book 799 of 15000 books.
# Info downloaded for book 800 of 15000 books.
# Info downloaded for book 801 of 15000 books.
# Info downloaded for book 802 of 15000 books.
# Info downloaded for book 803 of 15000 books.
# Info downloaded for book 804 of 15000 books.
# Info downloaded for book 805 of 15000 books.
# Info downloaded for book 806 of 15000 books.
# Info downloaded for book 807 of 15000 books.
# Info downloaded for book 808 of 15000 books.
# Info downloaded for book 809 of 15000 books.
# Info downloaded for book 810 of 15000 books.
# Info downloaded for book 811 of 15000 books.
# Info downloaded for book 812 of 15000 books.
# Info downloaded for book 813 of 15000 books.
# Info downloaded for book 814 of 15000 books.
# Info downloaded for book 815 of 15000 books.
# Info downloaded for book 816 of 15000 books.
# Info downloaded for book 817 of 15000 books.
# Info downloaded for book 818 of 15000 books.
# Info downloaded for book 819 of 15000 books.
# Info downloaded for book 820 of 15000 books.
# Info downloaded for book 821 of 15000 books.
# Info downloaded for book 822 of 15000 books.
# Info downloaded for book 823 of 15000 books.
# Info downloaded for book 824 of 15000 books.
# Info downloaded for book 825 of 15000 books.
# Info downloaded for book 826 of 15000 books.
# Info downloaded for book 827 of 15000 books.
# Info downloaded for book 828 of 15000 books.
# Info downloaded for book 829 of 15000 books.
# Info downloaded for book 830 of 15000 books.
# Info downloaded for book 831 of 15000 books.
# Info downloaded for book 832 of 15000 books.
# Info downloaded for book 833 of 15000 books.
# Info downloaded for book 834 of 15000 books.
# Info downloaded for book 835 of 15000 books.
# Info downloaded for book 836 of 15000 books.
# Info downloaded for book 837 of 15000 books.
# Info downloaded for book 838 of 15000 books.
# Info downloaded for book 839 of 15000 books.
# Info downloaded for book 840 of 15000 books.
# Info downloaded for book 841 of 15000 books.
# Info downloaded for book 842 of 15000 books.
# Info downloaded for book 843 of 15000 books.
# Info downloaded for book 844 of 15000 books.
# Info downloaded for book 845 of 15000 books.
# Info downloaded for book 846 of 15000 books.
# Info downloaded for book 847 of 15000 books.
# Info downloaded for book 848 of 15000 books.
# Info downloaded for book 849 of 15000 books.
# Info downloaded for book 850 of 15000 books.
# Info downloaded for book 851 of 15000 books.
# Info downloaded for book 852 of 15000 books.
# Info downloaded for book 853 of 15000 books.
# Info downloaded for book 854 of 15000 books.
# Info downloaded for book 855 of 15000 books.
# Info downloaded for book 856 of 15000 books.
# Info downloaded for book 857 of 15000 books.
# Info downloaded for book 858 of 15000 books.
# Info downloaded for book 859 of 15000 books.
# Info downloaded for book 860 of 15000 books.
# Info downloaded for book 861 of 15000 books.
# Info downloaded for book 862 of 15000 books.
# Info downloaded for book 863 of 15000 books.
# Info downloaded for book 864 of 15000 books.
# Info downloaded for book 865 of 15000 books.
# Info downloaded for book 866 of 15000 books.
# Info downloaded for book 867 of 15000 books.
# Info downloaded for book 868 of 15000 books.
# Info downloaded for book 869 of 15000 books.
# Info downloaded for book 870 of 15000 books.
# Info downloaded for book 871 of 15000 books.
# Info downloaded for book 872 of 15000 books.
# Info downloaded for book 873 of 15000 books.
# Info downloaded for book 874 of 15000 books.
# Info downloaded for book 875 of 15000 books.
# Info downloaded for book 876 of 15000 books.
# Info downloaded for book 877 of 15000 books.
# Info downloaded for book 878 of 15000 books.
# Info downloaded for book 879 of 15000 books.
# Info downloaded for book 880 of 15000 books.
# Info downloaded for book 881 of 15000 books.
# Info downloaded for book 882 of 15000 books.
# Info downloaded for book 883 of 15000 books.
# Info downloaded for book 884 of 15000 books.
# Info downloaded for book 885 of 15000 books.
# Info downloaded for book 886 of 15000 books.
# Info downloaded for book 887 of 15000 books.
# Info downloaded for book 888 of 15000 books.
# Info downloaded for book 889 of 15000 books.
# Info downloaded for book 890 of 15000 books.
# Info downloaded for book 891 of 15000 books.
# Info downloaded for book 892 of 15000 books.
# Info downloaded for book 893 of 15000 books.
# Info downloaded for book 894 of 15000 books.
# Info downloaded for book 895 of 15000 books.
# Info downloaded for book 896 of 15000 books.
# Info downloaded for book 897 of 15000 books.
# Info downloaded for book 898 of 15000 books.
# Info downloaded for book 899 of 15000 books.
# Info downloaded for book 900 of 15000 books.
# Info downloaded for book 901 of 15000 books.
# Info downloaded for book 902 of 15000 books.
# Info downloaded for book 903 of 15000 books.
# Info downloaded for book 904 of 15000 books.
# Info downloaded for book 905 of 15000 books.
# Info downloaded for book 906 of 15000 books.
# Info downloaded for book 907 of 15000 books.
# Info downloaded for book 908 of 15000 books.
# Info downloaded for book 909 of 15000 books.
# Info downloaded for book 910 of 15000 books.
# Info downloaded for book 911 of 15000 books.
# Info downloaded for book 912 of 15000 books.
# Info downloaded for book 913 of 15000 books.
# Info downloaded for book 914 of 15000 books.
# Info downloaded for book 915 of 15000 books.
# Info downloaded for book 916 of 15000 books.
# Info downloaded for book 917 of 15000 books.
# Info downloaded for book 918 of 15000 books.
# Info downloaded for book 919 of 15000 books.
# Info downloaded for book 920 of 15000 books.
# Info downloaded for book 921 of 15000 books.
# Info downloaded for book 922 of 15000 books.
# Info downloaded for book 923 of 15000 books.
# Info downloaded for book 924 of 15000 books.
# Info downloaded for book 925 of 15000 books.
# Info downloaded for book 926 of 15000 books.
# Info downloaded for book 927 of 15000 books.
# Info downloaded for book 928 of 15000 books.
# Info downloaded for book 929 of 15000 books.
# Info downloaded for book 930 of 15000 books.
# Info downloaded for book 931 of 15000 books.
# Info downloaded for book 932 of 15000 books.
# Info downloaded for book 933 of 15000 books.
# Info downloaded for book 934 of 15000 books.
# Info downloaded for book 935 of 15000 books.
# Info downloaded for book 936 of 15000 books.
# Info downloaded for book 937 of 15000 books.
# Info downloaded for book 938 of 15000 books.
# Info downloaded for book 939 of 15000 books.
# Info downloaded for book 940 of 15000 books.
# Info downloaded for book 941 of 15000 books.
# Info downloaded for book 942 of 15000 books.
# Info downloaded for book 943 of 15000 books.
# Info downloaded for book 944 of 15000 books.
# Info downloaded for book 945 of 15000 books.
# Info downloaded for book 946 of 15000 books.
# Info downloaded for book 947 of 15000 books.
# Info downloaded for book 948 of 15000 books.
# Info downloaded for book 949 of 15000 books.
# Info downloaded for book 950 of 15000 books.
# Info downloaded for book 951 of 15000 books.
# Info downloaded for book 952 of 15000 books.
# Info downloaded for book 953 of 15000 books.
# Info downloaded for book 954 of 15000 books.
# Info downloaded for book 955 of 15000 books.
# Info downloaded for book 956 of 15000 books.
# Info downloaded for book 957 of 15000 books.
# Info downloaded for book 958 of 15000 books.
# Info downloaded for book 959 of 15000 books.
# Info downloaded for book 960 of 15000 books.
# Info downloaded for book 961 of 15000 books.
# Info downloaded for book 962 of 15000 books.
# Info downloaded for book 963 of 15000 books.
# Info downloaded for book 964 of 15000 books.
# Info downloaded for book 965 of 15000 books.
# Info downloaded for book 966 of 15000 books.
# Info downloaded for book 967 of 15000 books.
# Info downloaded for book 968 of 15000 books.
# Info downloaded for book 969 of 15000 books.
# Info downloaded for book 970 of 15000 books.
# Info downloaded for book 971 of 15000 books.
# Info downloaded for book 972 of 15000 books.
# Info downloaded for book 973 of 15000 books.
# Info downloaded for book 974 of 15000 books.
# Info downloaded for book 975 of 15000 books.
# Info downloaded for book 976 of 15000 books.
# Info downloaded for book 977 of 15000 books.
# Info downloaded for book 978 of 15000 books.
# Info downloaded for book 979 of 15000 books.
# Info downloaded for book 980 of 15000 books.
# Info downloaded for book 981 of 15000 books.
# Info downloaded for book 982 of 15000 books.
# Info downloaded for book 983 of 15000 books.
# Info downloaded for book 984 of 15000 books.
# Info downloaded for book 985 of 15000 books.
# Info downloaded for book 986 of 15000 books.
# Info downloaded for book 987 of 15000 books.
# Info downloaded for book 988 of 15000 books.
# Info downloaded for book 989 of 15000 books.
# Info downloaded for book 990 of 15000 books.
# Info downloaded for book 991 of 15000 books.
# Info downloaded for book 992 of 15000 books.
# Info downloaded for book 993 of 15000 books.
# Info downloaded for book 994 of 15000 books.
# Info downloaded for book 995 of 15000 books.
# Info downloaded for book 996 of 15000 books.
# Info downloaded for book 997 of 15000 books.
# Info downloaded for book 998 of 15000 books.
# Info downloaded for book 999 of 15000 books.
# Info downloaded for book 1000 of 15000 books.
# Info downloaded for book 1001 of 15000 books.
# Info downloaded for book 1002 of 15000 books.
# Info downloaded for book 1003 of 15000 books.
# Info downloaded for book 1004 of 15000 books.
# Info downloaded for book 1005 of 15000 books.
# Info downloaded for book 1006 of 15000 books.
# Info downloaded for book 1007 of 15000 books.
# Info downloaded for book 1008 of 15000 books.
# Info downloaded for book 1009 of 15000 books.
# Info downloaded for book 1010 of 15000 books.
# Info downloaded for book 1011 of 15000 books.
# Info downloaded for book 1012 of 15000 books.
# Info downloaded for book 1013 of 15000 books.
# Info downloaded for book 1014 of 15000 books.
# Info downloaded for book 1015 of 15000 books.
# Info downloaded for book 1016 of 15000 books.
# Info downloaded for book 1017 of 15000 books.
# Info downloaded for book 1018 of 15000 books.
# Info downloaded for book 1019 of 15000 books.
# Info downloaded for book 1020 of 15000 books.
# Info downloaded for book 1021 of 15000 books.
# Info downloaded for book 1022 of 15000 books.
# Info downloaded for book 1023 of 15000 books.
# Info downloaded for book 1024 of 15000 books.
# Info downloaded for book 1025 of 15000 books.
# Info downloaded for book 1026 of 15000 books.
# Info downloaded for book 1027 of 15000 books.
# Info downloaded for book 1028 of 15000 books.
# Info downloaded for book 1029 of 15000 books.
# Info downloaded for book 1030 of 15000 books.
# Info downloaded for book 1031 of 15000 books.
# Info downloaded for book 1032 of 15000 books.
# Info downloaded for book 1033 of 15000 books.
# Info downloaded for book 1034 of 15000 books.
# Info downloaded for book 1035 of 15000 books.
# Info downloaded for book 1036 of 15000 books.
# Info downloaded for book 1037 of 15000 books.
# Info downloaded for book 1038 of 15000 books.
# Info downloaded for book 1039 of 15000 books.
# Info downloaded for book 1040 of 15000 books.
# Info downloaded for book 1041 of 15000 books.
# Info downloaded for book 1042 of 15000 books.
# Info downloaded for book 1043 of 15000 books.
# Info downloaded for book 1044 of 15000 books.
# Info downloaded for book 1045 of 15000 books.
# Info downloaded for book 1046 of 15000 books.
# Info downloaded for book 1047 of 15000 books.
# Info downloaded for book 1048 of 15000 books.
# Info downloaded for book 1049 of 15000 books.
# Info downloaded for book 1050 of 15000 books.
# Info downloaded for book 1051 of 15000 books.
# Info downloaded for book 1052 of 15000 books.
# Info downloaded for book 1053 of 15000 books.
# Info downloaded for book 1054 of 15000 books.
# Info downloaded for book 1055 of 15000 books.
# Info downloaded for book 1056 of 15000 books.
# Info downloaded for book 1057 of 15000 books.
# Info downloaded for book 1058 of 15000 books.
# Info downloaded for book 1059 of 15000 books.
# Info downloaded for book 1060 of 15000 books.
# Info downloaded for book 1061 of 15000 books.
# Info downloaded for book 1062 of 15000 books.
# Info downloaded for book 1063 of 15000 books.
# Info downloaded for book 1064 of 15000 books.
# Info downloaded for book 1065 of 15000 books.
# Info downloaded for book 1066 of 15000 books.
# Info downloaded for book 1067 of 15000 books.
# ...
# Info downloaded for book 1329 of 15000 books.
# Info downloaded for book 1330 of 15000 books.
# Info downloaded for book 1331 of 15000 books.
# Info downloaded for book 1332 of 15000 books.
# Info downloaded for book 1333 of 15000 books.
# Info downloaded for book 1334 of 15000 books.
# Info downloaded for book 1335 of 15000 books.
# Info downloaded for book 1336 of 15000 books.
# Info downloaded for book 1337 of 15000 books.
# Info downloaded for book 1338 of 15000 books.
# Info downloaded for book 1339 of 15000 books.
# Info downloaded for book 1340 of 15000 books.
# Info downloaded for book 1341 of 15000 books.
# Info downloaded for book 1342 of 15000 books.
# Info downloaded for book 1343 of 15000 books.
# Info downloaded for book 1344 of 15000 books.
# Info downloaded for book 1345 of 15000 books.
# Info downloaded for book 1346 of 15000 books.
# Info downloaded for book 1347 of 15000 books.
# Info downloaded for book 1348 of 15000 books.
# Info downloaded for book 1349 of 15000 books.
# Info downloaded for book 1350 of 15000 books.
# Info downloaded for book 1351 of 15000 books.
# Info downloaded for book 1352 of 15000 books.
# Info downloaded for book 1353 of 15000 books.
# Info downloaded for book 1354 of 15000 books.
# Info downloaded for book 1355 of 15000 books.
# Info downloaded for book 1356 of 15000 books.
# Info downloaded for book 1357 of 15000 books.
# Info downloaded for book 1358 of 15000 books.
# Info downloaded for book 1359 of 15000 books.
# Info downloaded for book 1360 of 15000 books.
# Info downloaded for book 1361 of 15000 books.
# Info downloaded for book 1362 of 15000 books.
# Info downloaded for book 1363 of 15000 books.
# Info downloaded for book 1364 of 15000 books.
# Info downloaded for book 1365 of 15000 books.
# Info downloaded for book 1366 of 15000 books.
# Info downloaded for book 1367 of 15000 books.
# Info downloaded for book 1368 of 15000 books.
# Info downloaded for book 1369 of 15000 books.
# Info downloaded for book 1370 of 15000 books.
# Info downloaded for book 1371 of 15000 books.
# Info downloaded for book 1372 of 15000 books.
# Info downloaded for book 1373 of 15000 books.
# Info downloaded for book 1374 of 15000 books.
# Info downloaded for book 1375 of 15000 books.
# Info downloaded for book 1376 of 15000 books.
# Info downloaded for book 1377 of 15000 books.
# Info downloaded for book 1378 of 15000 books.
# Info downloaded for book 1379 of 15000 books.
# Info downloaded for book 1380 of 15000 books.
# Info downloaded for book 1381 of 15000 books.
# Info downloaded for book 1382 of 15000 books.
# Info downloaded for book 1383 of 15000 books.
# Info downloaded for book 1384 of 15000 books.
# Info downloaded for book 1385 of 15000 books.
# Info downloaded for book 1386 of 15000 books.
# Info downloaded for book 1387 of 15000 books.
# Info downloaded for book 1388 of 15000 books.
# Info downloaded for book 1389 of 15000 books.
# Info downloaded for book 1390 of 15000 books.
# Info downloaded for book 1391 of 15000 books.
# Info downloaded for book 1392 of 15000 books.
# Info downloaded for book 1393 of 15000 books.
# Info downloaded for book 1394 of 15000 books.
# Info downloaded for book 1395 of 15000 books.
# Info downloaded for book 1396 of 15000 books.
# Info downloaded for book 1397 of 15000 books.
# Info downloaded for book 1398 of 15000 books.
# Info downloaded for book 1399 of 15000 books.
# Info downloaded for book 1400 of 15000 books.
# Info downloaded for book 1401 of 15000 books.
# Info downloaded for book 1402 of 15000 books.
# Info downloaded for book 1403 of 15000 books.
# Info downloaded for book 1404 of 15000 books.
# Info downloaded for book 1405 of 15000 books.
# Info downloaded for book 1406 of 15000 books.
# Info downloaded for book 1407 of 15000 books.
# Info downloaded for book 1408 of 15000 books.
# Info downloaded for book 1409 of 15000 books.
# Info downloaded for book 1410 of 15000 books.
# Info downloaded for book 1411 of 15000 books.
# Info downloaded for book 1412 of 15000 books.
# Info downloaded for book 1413 of 15000 books.
# Info downloaded for book 1414 of 15000 books.
# Info downloaded for book 1415 of 15000 books.
# Info downloaded for book 1416 of 15000 books.
# Info downloaded for book 1417 of 15000 books.
# Info downloaded for book 1418 of 15000 books.
# Info downloaded for book 1419 of 15000 books.
# Info downloaded for book 1420 of 15000 books.
# Info downloaded for book 1421 of 15000 books.
# Info downloaded for book 1422 of 15000 books.
# Info downloaded for book 1423 of 15000 books.
# Info downloaded for book 1424 of 15000 books.
# Info downloaded for book 1425 of 15000 books.
# Info downloaded for book 1426 of 15000 books.
# Info downloaded for book 1427 of 15000 books.
# Info downloaded for book 1428 of 15000 books.
# Info downloaded for book 1429 of 15000 books.
# Info downloaded for book 1430 of 15000 books.
# Info downloaded for book 1431 of 15000 books.
# Info downloaded for book 1432 of 15000 books.
# Info downloaded for book 1433 of 15000 books.
# Info downloaded for book 1434 of 15000 books.
# Info downloaded for book 1435 of 15000 books.
# Info downloaded for book 1436 of 15000 books.
# Info downloaded for book 1437 of 15000 books.
# Info downloaded for book 1438 of 15000 books.
# Info downloaded for book 1439 of 15000 books.
# Info downloaded for book 1440 of 15000 books.
# Info downloaded for book 1441 of 15000 books.
# Info downloaded for book 1442 of 15000 books.
# Info downloaded for book 1443 of 15000 books.
# Info downloaded for book 1444 of 15000 books.
# Info downloaded for book 1445 of 15000 books.
# Info downloaded for book 1446 of 15000 books.
# Info downloaded for book 1447 of 15000 books.
# Info downloaded for book 1448 of 15000 books.
# Info downloaded for book 1449 of 15000 books.
# Info downloaded for book 1450 of 15000 books.
# Info downloaded for book 1451 of 15000 books.
# Info downloaded for book 1452 of 15000 books.
# Info downloaded for book 1453 of 15000 books.
# Info downloaded for book 1454 of 15000 books.
# Info downloaded for book 1455 of 15000 books.
# Info downloaded for book 1456 of 15000 books.
# Info downloaded for book 1457 of 15000 books.
# Info downloaded for book 1458 of 15000 books.
# Info downloaded for book 1459 of 15000 books.
# Info downloaded for book 1460 of 15000 books.
# Info downloaded for book 1461 of 15000 books.
# Info downloaded for book 1462 of 15000 books.
# Info downloaded for book 1463 of 15000 books.
# Info downloaded for book 1464 of 15000 books.
# Info downloaded for book 1465 of 15000 books.
# Info downloaded for book 1466 of 15000 books.
# Info downloaded for book 1467 of 15000 books.
# Info downloaded for book 1468 of 15000 books.
# Info downloaded for book 1469 of 15000 books.
# Info downloaded for book 1470 of 15000 books.
# Info downloaded for book 1471 of 15000 books.
# Info downloaded for book 1472 of 15000 books.
# Info downloaded for book 1473 of 15000 books.
# Info downloaded for book 1474 of 15000 books.
# Info downloaded for book 1475 of 15000 books.
# Info downloaded for book 1476 of 15000 books.
# Info downloaded for book 1477 of 15000 books.
# Info downloaded for book 1478 of 15000 books.
# Info downloaded for book 1479 of 15000 books.
# Info downloaded for book 1480 of 15000 books.
# Info downloaded for book 1481 of 15000 books.
# Info downloaded for book 1482 of 15000 books.
# Info downloaded for book 1483 of 15000 books.
# Info downloaded for book 1484 of 15000 books.
# Info downloaded for book 1485 of 15000 books.
# Info downloaded for book 1486 of 15000 books.
# Info downloaded for book 1487 of 15000 books.
# Info downloaded for book 1488 of 15000 books.
# Info downloaded for book 1489 of 15000 books.
# Info downloaded for book 1490 of 15000 books.
# Info downloaded for book 1491 of 15000 books.
# Info downloaded for book 1492 of 15000 books.
# Info downloaded for book 1493 of 15000 books.
# Info downloaded for book 1494 of 15000 books.
# Info downloaded for book 1495 of 15000 books.
# Info downloaded for book 1496 of 15000 books.
# Info downloaded for book 1497 of 15000 books.
# Info downloaded for book 1498 of 15000 books.
# Info downloaded for book 1499 of 15000 books.
# Info downloaded for book 1500 of 15000 books.
# Info downloaded for book 1501 of 15000 books.
# Info downloaded for book 1502 of 15000 books.
# Info downloaded for book 1503 of 15000 books.
# Info downloaded for book 1504 of 15000 books.
# Info downloaded for book 1505 of 15000 books.
# Info downloaded for book 1506 of 15000 books.
# Info downloaded for book 1507 of 15000 books.
# Info downloaded for book 1508 of 15000 books.
# Info downloaded for book 1509 of 15000 books.
# Info downloaded for book 1510 of 15000 books.
# Info downloaded for book 1511 of 15000 books.
# Info downloaded for book 1512 of 15000 books.
# Info downloaded for book 1513 of 15000 books.
# Info downloaded for book 1514 of 15000 books.
# Info downloaded for book 1515 of 15000 books.
# Info downloaded for book 1516 of 15000 books.
# Info downloaded for book 1517 of 15000 books.
# Info downloaded for book 1518 of 15000 books.
# Info downloaded for book 1519 of 15000 books.
# Info downloaded for book 1520 of 15000 books.
# Info downloaded for book 1521 of 15000 books.
# Info downloaded for book 1522 of 15000 books.
# Info downloaded for book 1523 of 15000 books.
# Info downloaded for book 1524 of 15000 books.
# Info downloaded for book 1525 of 15000 books.
# Info downloaded for book 1526 of 15000 books.
# Info downloaded for book 1527 of 15000 books.
# Info downloaded for book 1528 of 15000 books.
# Info downloaded for book 1529 of 15000 books.
# Info downloaded for book 1530 of 15000 books.
# Info downloaded for book 1531 of 15000 books.
# Info downloaded for book 1532 of 15000 books.
# Info downloaded for book 1533 of 15000 books.
# Info downloaded for book 1534 of 15000 books.
# Info downloaded for book 1535 of 15000 books.
# Info downloaded for book 1536 of 15000 books.
# Info downloaded for book 1537 of 15000 books.
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1662                     if errno != 0:
# -> 1663                         raise SysCallError(errno, errorcode.get(errno))
#    1664                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     490             except OpenSSL.SSL.Error as e:
# --> 491                 raise ssl.SSLError("bad handshake: %r" % e)
#     492             break
#
# SSLError: ("bad handshake: SysCallError(10060, 'WSAETIMEDOUT')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='api2.isbndb.com', port=443): Max retries exceeded with url: /book/9780153178344 (Caused by SSLError(SSLError("bad handshake: SysCallError(10060, 'WSAETIMEDOUT')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-4-67bbf324646c> in <module>
#       3     header = {'Authorization': '44023_23ab132f3977ad9849e8f1a5d7dc73bf'}
#       4     base_url = ('https://api2.isbndb.com/book/')
# ----> 5     response = requests.get(base_url + isbn['isbn'][j], headers=header)
#       6     payload = response.json()
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api2.isbndb.com', port=443): Max retries exceeded with url: /book/9780153178344 (Caused by SSLError(SSLError("bad handshake: SysCallError(10060, 'WSAETIMEDOUT')")))

# %%
now = datetime.now()
dt = now.strftime("%d-%m-%Y_%H-%M-%S")

isbn.to_csv('../data/saved/isbn' + dt +'.csv', index = False)

# %% [markdown]
# ### Image acquisition

# %%
images = pd.read_csv('../data/processed/canadian_books.csv')
images = images.applymap(str)
images.dtypes
# Out:
# id             object
# title          object
# author         object
# description    object
# image          object
# dtype: object

# %%
images = images[:10]
images
# Out:
#   id                                              title            author  \
# 0  1           01 Nathaniel Mcdaniel and Bigbeards Hook      Evan Solomon
# 1  2  02 Standard of Honor Book Two of the Templar T...        Jack Whyte
# 2  3                  03 Knights Templar Order in Chaos        Jack Whyte
# 3  4  100 Easy-to-Grow Native Plants for Canadian Ga...  Lorraine Johnson
# 4  5                                           10 Women   George Bowering
#
#                                          description  \
# 0  Meet Nathaniel McDaniel, the mischievous hero ...
# 1  Jack Whyte’s thrilling Templar Trilogy continu...
# 2  In the final novel in the Templar Trilogy, Wil...
# 3  The key to a carefree garden is to know which ...
# 4  Ten Women is a new collection of short fiction...
#
#                                                image
# 0  https://images.49thshelf.com/var/ezflow_site/s...
# 1  https://images.49thshelf.com/var/ezflow_site/s...
# 2  https://images.49thshelf.com/var/ezflow_site/s...
# 3  https://images.49thshelf.com/var/ezflow_site/s...
# 4  https://images.49thshelf.com/var/ezflow_site/s...

# %%
for i in range(len(images)):

    try:
        urllib.request.urlretrieve(images['image'][i], '../img/books/' + id[i] + '.jpg')
        print('Just captured image number ' + images['id'][i])

    except:
        print('Failed to capture image number ' + images['id'][i])
        
    time.sleep(2)
# Out:
# Failed to capture image number 1
# Failed to capture image number 2
# Failed to capture image number 3
# Failed to capture image number 4
# Failed to capture image number 5
